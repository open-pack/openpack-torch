# %% [markdown]
# # OpenPack Challenge | Tutorial: OpenPack Datasetの概要とモデリングの考え方

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/open-pack/openpack-torch/blob/main/examples/deep-conv-lstm/notebooks/Tutorial_Basics_of_Modeling__JA.ipynb)

# %% [markdown]
# NOTE: colabで実行する場合は，実行前にランタイムを "GPU" に変更してください．
#
# NOTE: このNotebookにはコンペに提出する`submission.json`を作成するための手順は含まれていません．他のチュートリアルを参考にしてください．

# %% [markdown]
# ## [1] はじめに
#
# このノートブックは， [Percom 2023 Workshop　BiRD](https://bio-navigation.jp/bird2023/) で開催される行動認識コンペティション 「[OpenPack Challenge　2022](https://open-pack.github.io/challenge2022)」の参加者用チュートリアルとして作成しました．
# このチュートリアルでは， (1) OpenPackの概要とタスクの説明， (2) 行動認識モデルのサンプルプログラムの実行を行います．
# OpenPackデータセットのデータの性質を捉え， 梱包作業という作業行動を認識するためのモデリングの考え方を学んで行きましょう．

# %% [markdown]
# ### 1-1: OpenPack Challenge 2022 (データ分析コンペティション)
#
# [Percom 2023 Workshop](https://bio-navigation.jp/bird2023/)で，OpenPack Datasetを使用したデータ分析コンペの開催を予定しています．
# コンペのタスクはこのノートブックで説明するものと同じく， 10種類の作業工程の分類 (temporal semantic segmentation) です．
# コンペの詳細につきましては [HP](https://open-pack.github.io/challenge2022) をご参照ください．
# また，　このチュートリアルを通して作業工程の認識に興味を持っていただけましたら，　ぜひコンペへの参加もご検討いただけると嬉しく思います．
#
# - [OpenPack Challenge 2022 - Official Site](https://open-pack.github.io/challenge2022)
# - [Google Group](https://groups.google.com/g/openpack) (コンペの最新情報を受け取りたい方は，こちらのメーリングリストにご登録ください．)
#
# ![](../../assets/img/OpenPackCHALLENG-black.png)

# %% [markdown]
# ### 1-2: このチュートリアルの学習対象者
#
# - OpenPack Challengeの参加者または参加を検討している方
# - OpenPack Datasetの概要を把握したい方
# - 機械学習 (Neural Network) のモデリングの基礎に触れたい方
#
# このチュートリアルを実行するにあたって，高度な機械学習の知識は必要としませんが，　機械学習の基本に関しては知識があることが望ましいです．

# %% [markdown]
# ## [2] OpenPack Datasetの概要

# %% [markdown]
# **OpenPack Dataset**は， 産業ドメインにおける大規模マルチモーダルデータセットです．
# 物流センターの梱包作業に注目し， 16名の被験者が商品を段ボールに梱包する作業を， 深度センサやIMUセンサなど 9種類のセンサーで記録しました．
# データセットのサイズは53時間超であり，産業ドメインのデータセットでは最大級です．

# %% [markdown]
# OpenPackの特徴を簡単にまとめました．　詳細は[HP](https://open-pack.github.io)を参照してください．
#
# > **OpenPack Datasetの特徴**
# > 1. 合計53時間を超える大規模な，産業ドメインの行動認識データセット．
# > 1. 9種類のセンサの種類に加え， スマート工場に導入されているIoT機器のデータを含む．
# > 1. 作業者の梱包作業の経験や， 梱包する商品など豊富なメタデータを収集．

# %% [markdown]
# OpenPack Datasetは，行動認識研究のためのデータセットであり，　以下の10種類の作業工程に対してラベルが付与されています(下図のAnnotation/Operationの段)．
# このノートブックでは， 与えられたセンサデータに対して1秒単位でどの行動が行われているかを推定します．
# [Youtube](https://youtu.be/KRG5zv3ueRQ) にサンプル動画 (深度画像)をアップロードしています． こちらを見ていただければ，梱包作業の具体的な流れが掴めると思います．
#
# > **OpenPack: Activity Class (作業工程)**
# > - 100: Picking (梱包する商品を持ってくる.)
# > - 200: Relocate Item Label (商品についているラベルを梱包リストに張り替える.)
# > - 300: Assemble Box (段ボールを組み立てる.)
# > - 400: Insert Items (組み立てた段ボールに商品を詰める.)
# > - 500: Close Box (段ボールを閉じる.)
# > - 600: Attach Box Label (箱番号シールを貼り付ける.)
# > - 700: Scan Label (複数のバーコードをスキャンする.)
# > - 800: Attaching Shipping Label (出荷ラベルをつける.)
# > - 900: Put on Back Table (梱包した箱を後ろのテーブルに片付ける.)
# > - 1000: Fill out Order (梱包リストの確認欄を記入し， 片付ける.)

# %% [markdown]
# OpenPack Datasetの主なタスクは 「梱包作業における作業工程の認識」です．
# しかし，その認識は簡単ではありません．
# 例えば，「Walk」を認識したい場合は，手足の周期的な動きを捉えれば良いですが，作業工程の場合繰り返される動きが非常に少ない上，以下のような課題にも対処する必要があります．
#
# 1. 被験者の熟練度によって，動作のスピードが大きく異なります．
# 1. 梱包する商品の組み合わせが毎回異なります． 商品のサイズによって使用する箱のサイズも変わります． さらに，商品の数が異なれば，箱に入れる動作の回数が変わります．
# 1. 作業の手順は基本的に決まっていますが，より効率的な作業のために熟練者は手順を一部変更したり， 間違いによって順番が変更されます．

# %% [markdown]
# ![](../../assets/img/OpenPack__KeyVisual.png)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('KRG5zv3ueRQ', width=600, height=400)

# %% [markdown]
# ## [3] 行動認識のサンプルプログラムの実行

# %% [markdown]
# ここから先では， 左右の手首に装着したIMUセンサーで収集した加速度データを入力として， 1秒単位で10種類の作業工程のどれが行われているかを推定する Neural Networkの構築を行います．
# ここでは，モデリングの基本アイデアを学ぶことに注目してほしいので，学習に必要なコードは複数ありますが，特に指示がないところはそのまま実行してください．
# データの前処理や学習方法の変更などの発展的な実験に挑戦したい場合は，別のチュートリアルで理解を深めていただけると幸いです．
#
# - 入力: 左右手首から30Hzで収集した加速度信号 60秒 (入力するTensorのShape: `(1800, 6)`)
# - 出力: 1秒後ごとの作業工程ラベル (TensorのShape: `(60, 10)`)
# - モデル: Neural Network (PyTorch)

# %% [markdown]
# ![](../../assets/img/tutorial/task_JA.jpg)

# %% [markdown]
# ### Neural Networkとは？
#
# 人間の神経細胞から着想を得た，機械学習モデルの一つです．
# 最初はランダムな値を主力しますが，入力データと正解ラベルの関係を「学習」することで，高精度で予測ができるようになります．

# %% [markdown]
# ### 行動認識モデルのモデリング
#
# ここでは，行動認識モデルを構成するためにどのような視点を持てば良いかということを簡単にまとめます．
# 具体的な実装や選択は下のサンプルを実行しながら説明します．
# まず，マルチモーダルな時系列データを扱うにあたって，考えるべきことの例を以下にまとめました．
#
# 1. 時間方向の依存関係
#     1. 考慮する範囲 (1秒間?，10秒間?) ... 認識対象の行動の継続時間などを参考に設定します．
#     1. 順方向の時間発展 (時間を進める方向) のみ考慮するか，逆方向 (時間を巻き戻す方向)も考慮するか?　... 「タップ」と「ダブルタップ」を分類するとき， 1回目のタップがどちらか見分けるためには過去と未来両方から攻める必要があります．
# 1. モダリティの扱い
#     1. センサーフュージョン (両手の動きをまとめて特徴抽出する? OR 右左別々に特徴抽出を行なったあとで組み合わせる？) ... 左右の手は独立に動くことができるので，分けて考えた方が効果的な場合があります．
#     1. 他のモダリティ (動画，IoT デバイスのログ, etc) との組み合わせ方
#
#
# このチュートリアルで全てを扱うことは難しいので，**1. 時間方向の依存関係** について考えていきたいと思います．

# %% [markdown]
# ### OpenPack Datasetの梱包作業に着目したモデリングのポイント
#
# 基本的には上の2項目と同じですが，よりOpenPack Datasetに特化したポイントを説明します．
#
# - 手だけを使った動作が中心です．そのため，加速度データだけでは非常に似通った動作が多く存在します．
#     - e.g.) 腕の移動, Assemble Box と Close Box
#     - 特徴抽出する範囲をできるだけ広くとって，**前後の作業工程を手がかりに注目した時刻の動作を推定**することが有効だと考えられます．
# - 行動の出現順序は基本的に決まっています．
#     - 作業手順が決まっているため，行動クラスの出現順序もおおよそ決まっています．
#     - この**行動の出現順序は予測を行う上で大きなヒント**となります．
#     - (注意) ある程度精度が高まると，作業ミスなどで通常の順序から外れる場合の誤認識が課題となります．　より精度を高めるためには．この部分をどう扱うかがより精度を高めるために重要になります．

# %% [markdown]
# ![](../../assets/img/tutorial/work_HAR_idea_JA.jpg)

# %% [markdown]
# ------
# ここからは，実装パートになります．

# %% [markdown]
# ## [4] 環境の初期化 (Notebookを開いて初回のみ実行)
# 細かい説明は省きます．ひとまず，以下のコードを順番に実行してください．

# %% [markdown]
# ### 4-1: Download Code and Install `openpack-torch`

# %%
# サンプルコードのダウンロード
! cd /content && git clone https://github.com/open-pack/openpack-torch.git

# %%
# 関連パッケージのダウンロード
! cd /content/openpack-torch/ && pip install .

# %% [markdown]
# ### 4-2: データセットのダウンロード

# %% [markdown]
# NOTE: Colabを使用している場合は，このセルを実行しGoogle Driveをマウントする．

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# データセットのダウンロード (ダウンロード先: `/content/drive/MyDrive/Colab Notebooks/openpack/data/datasets`)

# %%
# NOTE: If you have already downloaded the dataset, you can skip this cell.
! mkdir -p "/content/drive/MyDrive/Colab Notebooks/openpack/data/datasets"
! wget https://raw.githubusercontent.com/open-pack/openpack-toolkit/main/tools/download/dl_from_zenodo.sh
! bash ./dl_from_zenodo.sh "/content/drive/MyDrive/Colab Notebooks/openpack/data/datasets"

# %%
! ln -s "/content/drive/MyDrive/Colab Notebooks/openpack/data/" "/content/data"

# %%
! ls -la "/content/data/datasets/openpack/v1.0.0"
# Out:
# total 100
# drwxrwsr-x 25 1001 240 4096 Nov 19 11:21 .
# drwxrwsr-x  3 1001 240 4096 Nov 19 09:56 ..
# drwxrwsr-x  7 1001 240 4096 Nov 19 10:06 U0101
# drwxrwsr-x  7 1001 240 4096 Nov 19 10:09 U0102
# drwxrwsr-x  7 1001 240 4096 Nov 19 10:12 U0103
# drwxrwsr-x  7 1001 240 4096 Nov 19 10:16 U0104
# drwxrwsr-x  7 1001 240 4096 Nov 19 10:19 U0105
# drwxrwsr-x  7 1001 240 4096 Nov 19 10:24 U0106
# drwxrwsr-x  7 1001 240 4096 Nov 19 10:28 U0107
# drwxrwsr-x  7 1001 240 4096 Nov 19 10:32 U0108
# drwxrwsr-x  7 1001 240 4096 Nov 19 10:37 U0109
# drwxrwsr-x  7 1001 240 4096 Nov 19 10:41 U0110
# drwxrwsr-x  7 1001 240 4096 Nov 19 10:46 U0111
# drwxrwsr-x  7 1001 240 4096 Nov 19 10:49 U0201
# drwxrwsr-x  7 1001 240 4096 Nov 19 10:53 U0202
# drwxrwsr-x  7 1001 240 4096 Nov 19 10:56 U0203
# drwxrwsr-x  7 1001 240 4096 Nov 19 11:00 U0204
# drwxrwsr-x  7 1001 240 4096 Nov 19 11:05 U0205
# drwxrwsr-x  7 1001 240 4096 Nov 19 11:08 U0206
# drwxrwsr-x  7 1001 240 4096 Nov 19 11:11 U0207
# drwxrwsr-x  7 1001 240 4096 Nov 19 11:14 U0208
# drwxrwsr-x  7 1001 240 4096 Nov 19 11:18 U0209
# drwxrwsr-x  7 1001 240 4096 Nov 19 11:21 U0210
# drwxrwsr-x  3 1001 240 4096 Nov 19 10:02 preprocessed
# drwxrwsr-x  2 1001 240 4096 Nov 19 11:18 zenodo

# %% [markdown]
# ### 4-3: モジュールのインポート

# %%
import logging
from logging import getLogger
from pathlib import Path
from typing import Dict, Optional

import hydra
import openpack_toolkit as optk
import pytorch_lightning as pl
import torch
import pandas as pd
import numpy as np
from omegaconf import DictConfig, OmegaConf
from scipy.special import softmax
from torch import nn

import matplotlib.pyplot as plt
import seaborn as sns

import openpack_torch as optorch
from openpack_torch.lightning import EarlyStopError
from openpack_torch.utils.test_helper import test_helper

from openpack_toolkit import ActSet
from openpack_toolkit.configs.datasets.annotations import (
    OPENPACK_ACTIONS,
    OPENPACK_OPERATIONS,
)
from openpack_toolkit.codalab.operation_segmentation import (
    construct_submission_dict, eval_operation_segmentation_wrapper,
    make_submission_zipfile)

sns.set("notebook", "whitegrid")

# %%
_ = optk.utils.notebook.setup_root_logger()
logger = logging.getLogger(__name__)

logger.debug("debug")
logger.info("info")
logger.warning("warning")
# Out:
# 2023-11-23 09:00:59 | INFO | __main__ | info
# 2023-11-23 09:00:59 | WARNING | __main__ | warning

# %%
optorch.utils.reset_seed(seed=0)
optorch.configs.register_configs()
# Out:
# 2023-11-23 09:00:59 | INFO | openpack_torch.utils.random | Reset Seeds: python=0, numpy=0, Pytorch (cpu=0, cuda=0)

# %% [markdown]
# ### 4-4: 設定ファイルの読み込み
# パラメータなどのデフォルト値を読み込みます．こちらも詳細な説明は省きます．深層学習でモデルを組む場合は，非常に多くのハイパーパラメータ (手動で設定すべきパラメータ) があるため，これらを管理することは実験の再現性と効率を高めるために重要です．この問題を解決するために様々なツールが提案されていますが，ここでは　[hydra](https://hydra.cc/) を使用しています．

# %%
# Config Fileのサンプルをコピー
! cp -r /content/openpack-torch/examples/configs /content/

# %%
overrides = [
    "mode=train",
    "metadata.labels.issue=I01-EXP1-V1-nb", # subdirectry for logging
    
    # -- debug --
    # If true, some training parameters (e.g., bach size, epochs) are switched to debug mode setting written in `train.debug.XXX`.
    "debug=true",

    # -- path.logdir.rootdir --
    "path.openpack.version=v1.0.0",
    "path.openpack.rootdir=/content/data/datasets/openpack/${path.openpack.version}/",
    
    # -- path.logdir.rootdir --
    # path to write training logs and resutls.
    # If you want to keep logs, please use Google Drive (i.e., `/content/data/XXX` (symling to Google Drive), `/content/drive/XXX`)
    "path.logdir.rootdir=/content/data/log/${metadata.name}/${metadata.labels.issue}/${metadata.task}/${dataset.split.name}-split/${dataset.stream.name}/${model.name}/${metadata.labels.params}/RUN${run}",
    
    # "hydra/job_logging=custom",
    # "hydra/hydra_logging=disabled"
]

with hydra.initialize_config_dir(version_base=None, config_dir="/content/configs"):
    cfg = hydra.compose(
        config_name="deep-conv-lstm.yaml",
        overrides=overrides,
    )

# -- Data Split --
# Change Train/Val/Test/Submission set to submit for Development Phase.
# Please comment out the following block when you want to train on the main set.
# cfg.dataset.split = optk.configs.datasets.splits.DEBUG_SPLIT
cfg.dataset.split = optk.configs.datasets.splits.PILOT_CHALLENGE_SPLIT

# (default value)
# cfg.dataset.split = optk.configs.datasets.splits.OPENPACK_CHALLENGE_2022_SPLIT

# %%
print(OmegaConf.to_yaml(cfg))
# Out:
# run: 0
# debug: true
# mode: train
# path:
#   openpack:
#     version: v1.0.0
#     rootdir: /content/data/datasets/openpack/${path.openpack.version}/
#   datasets:
#     openpack: ${path.openpack.rootdir}
#   logdir:
#     rootdir: /content/data/log/${metadata.name}/${metadata.labels.issue}/${metadata.task}/${dataset.split.name}-split/${dataset.stream.name}/${model.name}/${metadata.labels.params}/RUN${run}
#     model: ${path.logdir.rootdir}/model.pth
#     predict: ${path.logdir.rootdir}/pred/${train.checkpoint}/{user}-{session}
#     summary:
#       rootdir: ${path.logdir.rootdir}/summary/${train.checkpoint}
#       train: ${.rootdir}/train.csv
#       test: ${.rootdir}/test.csv
#       test-b2: ${.rootdir}/test-b2.csv
#       test-b3: ${.rootdir}/test-b3.csv
#       submission: ${.rootdir}/submission.csv
# dataset:
#   annotation:
#     kind: dataset/annotation/csv/sequence
#     name: openpack-operations-1hz-annotation
#     metadata:
#       labels:
#         type: annotation/operation
#         version: v3.5.0
#         dependency: openpack-operations
#         resolution: 1Hz
#     spec:
#       path:
#         dir: ${path.openpack.rootdir}/${user.name}/annotation/openpack-operations-1hz
#         fname: ${session}.csv
#       classes:
#       - id: 100
#         name: Picking
#         description: Check the order-sheet and go to the back table to pick up the
#           items.
#         version: v3.0.0
#         ignore: false
#       - id: 200
#         name: Relocate Item Label
#         description: Peel off the label from the items and place it on the bottom
#           margin of the order sheet. Check the item names and quantity on the list
#           and label with a ballpoint pen. (When picking is done in one round trip,
#           this action is set as the beginning of the box.)
#         version: v3.2.2
#         ignore: false
#       - id: 300
#         name: Assemble Box
#         description: Assemble cardboard boxes that match the size of the items.
#         version: v3.2.2
#         ignore: false
#       - id: 400
#         name: Insert Items
#         description: Put the goods into the box. Fill the box with air cushion.
#         version: v3.2.2
#         ignore: false
#       - id: 500
#         name: Close Box
#         description: Close the box with craft tape.
#         version: v3.2.2
#         ignore: false
#       - id: 600
#         name: Attach Box Label
#         description: Attach the box number label to the side of the box.
#         version: v3.2.2
#         ignore: false
#       - id: 700
#         name: Scan Label
#         description: 'Scan barcodes with the handy scanner in the following order:
#           (1) order sheet, (2) box number sticker, (3) item label. Then press the
#           "ESC" button on the handy scanner twice. Next, scan barcodes with the scanner
#           of the label printer in the following order: (1) order sheet, (2) code on
#           the label printer.'
#         version: v3.2.2
#         ignore: false
#       - id: 800
#         name: Attach Shipping Label
#         description: Attach the shipping label printed out from the label printer
#           to the box.
#         version: v3.2.2
#         ignore: false
#       - id: 900
#         name: Put on Back Table
#         description: Move the completed packing box under the back table.
#         version: v3.2.2
#         ignore: false
#       - id: 1000
#         name: Fill out Order
#         description: Write their signatures in the confirmation column of the order
#           sheet and insert it into the tray for completed order sheets.
#         version: v3.2.2
#         ignore: false
#       - id: 8100
#         name: 'Null'
#         description: For the operation label, ID8200 is translated into this label
#           (ID8100).
#         version: v3.2.2
#         ignore: true
#   stream:
#     kind: dataset/stream/multimodal
#     name: atr02-iot
#     mdetadata:
#       labels:
#         app: openpack-benchmarks
#         version: 1.0.0
#         multimodal: true
#     spec:
#       imu:
#         kind: dataset/stream/imu
#         path:
#           dir: ${path.openpack.rootdir}/${user.name}/atr/${device}
#           fname: ${session}.csv
#           full_path: ${.dir}/${.fname}
#         devices:
#         - atr02
#         acc: true
#         gyro: false
#         quat: false
#       iot:
#         kind: dataset/stream/iot
#         spec:
#           anchor:
#             dim: 2
#             linked_class:
#               0: 6
#               1: 6
#           devices:
#             kind: dataset/stream/multimodal
#             spec:
#               ht:
#                 kind: dataset/stream
#                 spec:
#                   path:
#                     dir: ${path.openpack.rootdir}/${user.name}/system/ht
#                     fname: ${session}.csv
#               printer:
#                 kind: dataset/stream
#                 spec:
#                   path:
#                     dir: ${path.openpack.rootdir}/${user.name}/system/printer
#                     fname: ${session}.csv
#   split:
#     name: pilot-challenge
#     train:
#     - - U0102
#       - S0100
#     - - U0102
#       - S0200
#     - - U0102
#       - S0300
#     - - U0102
#       - S0400
#     - - U0102
#       - S0500
#     - - U0103
#       - S0100
#     - - U0103
#       - S0200
#     - - U0103
#       - S0300
#     - - U0103
#       - S0400
#     - - U0103
#       - S0500
#     - - U0105
#       - S0100
#     - - U0105
#       - S0200
#     - - U0105
#       - S0300
#     - - U0105
#       - S0400
#     - - U0105
#       - S0500
#     val:
#     - - U0106
#       - S0200
#     - - U0106
#       - S0400
#     test:
#     - - U0106
#       - S0100
#     - - U0106
#       - S0300
#     - - U0106
#       - S0500
#     submission:
#     - - U0107
#       - S0100
#     - - U0107
#       - S0200
#     - - U0107
#       - S0300
#     - - U0107
#       - S0500
#   classes:
#   - id: 100
#     name: Picking
#     version: v3.0.0
#     is_ignore: false
#     category: null
#     event: null
#   - id: 200
#     name: Relocate Item Label
#     version: v3.2.2
#     is_ignore: false
#     category: null
#     event: null
#   - id: 300
#     name: Assemble Box
#     version: v3.2.2
#     is_ignore: false
#     category: null
#     event: null
#   - id: 400
#     name: Insert Items
#     version: v3.2.2
#     is_ignore: false
#     category: null
#     event: null
#   - id: 500
#     name: Close Box
#     version: v3.2.2
#     is_ignore: false
#     category: null
#     event: null
#   - id: 600
#     name: Attach Box Label
#     version: v3.2.2
#     is_ignore: false
#     category: null
#     event: null
#   - id: 700
#     name: Scan Label
#     version: v3.2.2
#     is_ignore: false
#     category: null
#     event: null
#   - id: 800
#     name: Attach Shipping Label
#     version: v3.2.2
#     is_ignore: false
#     category: null
#     event: null
#   - id: 900
#     name: Put on Back Table
#     version: v3.2.2
#     is_ignore: false
#     category: null
#     event: null
#   - id: 1000
#     name: Fill out Order
#     version: v3.2.2
#     is_ignore: false
#     category: null
#     event: null
#   - id: 8100
#     name: 'Null'
#     version: v3.2.2
#     is_ignore: true
#     category: null
#     event: null
# optimizer:
#   name: adam-exp
#   type: Adam
#   lr: 0.001
#   weight_decay: 0.0001
#   scheduler:
#     type: ExponentialLR
#     gamma: 0.99
# model:
#   name: DCL
# metadata:
#   name: benchmark1
#   task: ${dataset.annotation.name}
#   labels:
#     app: openpack-benchmarks
#     issue: I01-EXP1-V1-nb
#     params: ${optimizer.name}/LR${optimizer.lr}
#     benchmarkType: benchmark1
# train:
#   num_workers: 3
#   batch_size: 32
#   epochs:
#     minimum: 300
#     maximum: 1000
#   window: 1800
#   checkpoint: last
#   random_crop: true
#   val_split_siz: 0.2
#   early_stop:
#     monitor: train/acc
#     min_delta: 0.001
#     patience: 30
#     verbose: false
#     mode: max
#   debug:
#     batch_size: 8
#     epochs:
#       minimum: 5
#       maximum: 10

# %% [markdown]
# ## [5] モデルの定義

# %% [markdown]
# ### 5-1: ベースとするモデルの概要 (DeepConvLSTM)
#
# このチュートリアルでは，DeepConvLSTM という2016年に発表されたモデルをベースに，様々なモデルを作っていきたいと思います．
# このモデルは，現在でもベースライン手法として多くの研究で利用されています．
# まず，畳み込み層 (convolution layer) で局所的な特徴を抽出した後，LSTM層で長期的な依存関係を抽出することで，短期的な依存関係と長期的な依存関係の両方を考慮するように設計されています．
#
# 参考: [Deep Convolutional and LSTM Recurrent Neural Networks for Multimodal Wearable Activity Recognition (Sensors, 2016)](https://www.mdpi.com/1424-8220/16/1/115)

# %% [markdown]
# ### 5-2: モデルの変更パターン
#
# 今回は次の3種類を用意しました．
#
# 1. CNNのみ
#     1. 畳み込みフィルタのサイズを変更して，特徴を抽出する時間の長さを変える.
#     1. CNN層の数を変える.
# 1. DeepConvLSTM (論文で提案されているモデル)
# 1. 双方向LSTM (LSTM層を，順方向&逆方向の両方を考慮するものを使用)

# %% [markdown]
# ![](../../assets/img/tutorial/dcl_architecture_JA.jpg)

# %% [markdown]
# ### 5-3: CNNのみ (ver.1)
#
# CNNのみを使用したモデルです．
# 特徴を抽出する時間の範囲は，(A) kernel size，(B) 畳み込み層の数を変更することで変えることができます．
# 畳み込み層はPyTorchで `Conv2d()` として定義されています．

# %% [markdown]
# #### 実験1-A: Kernel Sizeの変更
#
# センサーのサンプリングレートは30Hzです．
# つまり，Kernel Sizeを `ks=30` とすると，一回の畳み込み演算で1秒間の範囲から特徴抽出をすることができます．
# 実験では，以下の値に設定してモデルを学習してみて結果を比べてみましょう．
# ちなみに，OpenPackの作業工程の継続時間は作業工程により異なりますが，通常2秒 ~ 15秒です．
#
# - `ks=5` (0.16秒間; 論文のパラメータ)
# - `ks=15` (0.5秒間)
# - `ks=30` (1.0秒間)
# - `ks=60` (2.0秒間)

# %% [markdown]
# #### 実験1-B: 畳み込み層の数 (`num_conv_layers`)
#
# 畳み込み層を重ねることでも，特徴抽出の範囲を広げることができます．
# 以下の値を試してみてください．
#
# - `num_conv_layers = 1`
# - `num_conv_layers = 4` (論文のパラメータ)
# - `num_conv_layers = 8`

# %% [markdown]
# #### 実験1-C: Kernel Size x 畳み込み層の数
#
# 「Kernel Size」と「畳み込み層の数」はどちらも特徴を抽出する範囲を変えることができます．
# また，この２つのパラメータの組み合わせ方もとても重要です．
# 例えば，kernel sizeは小さく，層の数は多く設定することで，細かな特徴を捉えつつ徐々に長期的な依存関係を捉えることができます．
# 画像系のモデルでは，しばしばこのアプローチが採用されてきました．
# 逆に，Kernel Sizeを大きく設定し，層の数を減らすアプローチでは，畳み込む範囲が広いので局所的なノイズに強くすることができます．
# どのようなアプローチが良いか，実験してみてください．

# %% [markdown]
# ![](../../assets/img/tutorial/cnn_receptive_field_JA.jpg)

# %%
class DeepConvLstmV1(nn.Module):
    """CNNだけを使用するモデル
    """
    def __init__(self, in_ch: int = 3, num_classes: int = None):
        super().__init__()
        if num_classes is None:
            num_classes = len(OPENPACK_OPERATIONS)

        # -- [1] CNN (畳み込み層) --
        # *** Edit Here ***
        # NOTE: 実験1-A: Kernel Size (注意: 奇数を指定)
        ks = 5
        # NOTE: 実験1-B: 使用する畳み込み層の数 (Default: 4)
        num_conv_layers = 4
        # ******************
        num_conv_filter = 64 # 各層の畳み込みフィルタの数 (Default: 64)
        
        blocks = []
        for i in range(num_conv_layers):
            in_ch_ = in_ch if i == 0 else num_conv_filter 
            blocks.append(
                nn.Sequential(
                    nn.Conv2d(in_ch_, num_conv_filter, kernel_size=(ks, 1), padding=(ks//2, 0)),
                    nn.BatchNorm2d(num_conv_filter),
                    nn.ReLU(),
                )
            )
        self.conv_blocks = nn.ModuleList(blocks)

        # -- [3] 出力層 --
        self.out8 = nn.Conv2d(
            num_conv_filter,
            num_classes,
            1,
            stride=1,
            padding=0,
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        Args:
            x (torch.Tensor): shape = (B, CH, T, 1)
        Returns:
            torch.Tensor: shape = (B, N_CLASSES, T, 1)
        """
        # -- [1] Conv --
        for block in self.conv_blocks:
            x = block(x)
            
        # -- [3] 出力層 --
        x = self.out8(x)
        return x

# %% [markdown]
# ### 5-4: DeepConvLstm (ver.2)
#
# 論文で提案されているモデルの構成です．ver.1に対して，LSTM層が追加されています．
# LSTMによって，長期的な依存関係を学習することができるようになります．

# %%
class DeepConvLstm(nn.Module):
    """論文で提案されている構成
    """
    def __init__(self, in_ch: int = 3, num_classes: int = None):
        super().__init__()
        if num_classes is None:
            num_classes = len(OPENPACK_OPERATIONS)

        # -- [1] CNN (畳み込み層) --
        # *** Edit Here ***
        num_conv_layers = 4 # 使用する畳み込み層の数 (Default: 4)
        num_conv_filter = 64 # 各層の畳み込みフィルタの数 (Default: 64)
        ks = 5 # 畳み込みフィルタのサイズ; kernel size, 
        # ******************
        
        blocks = []
        for i in range(num_conv_layers):
            in_ch_ = in_ch if i == 0 else 64
            blocks.append(
                nn.Sequential(
                    nn.Conv2d(in_ch_, 64, kernel_size=(5, 1), padding=(2, 0)),
                    nn.BatchNorm2d(64),
                    nn.ReLU(),
                )
            )
        self.conv_blocks = nn.ModuleList(blocks)

        # -- [2] LSTM --
        # *** Edit Here ***        
        hidden_units = 128 # LSTM層の隠れニューロンの数
        # ******************
        
        self.lstm6 = nn.LSTM(num_conv_filter, hidden_units, batch_first=True)
        self.lstm7 = nn.LSTM(hidden_units, hidden_units, batch_first=True)
        self.dropout6 = nn.Dropout(p=0.5)
        self.dropout7 = nn.Dropout(p=0.5)

        # -- [3] 出力層 --
        self.out8 = nn.Conv2d(
            hidden_units,
            num_classes,
            1,
            stride=1,
            padding=0,
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        Args:
            x (torch.Tensor): shape = (B, CH, T, 1)
        Returns:
            torch.Tensor: shape = (B, N_CLASSES, T, 1)
        """
        # -- [1] Conv --
        for block in self.conv_blocks:
            x = block(x)

        # -- [2] LSTM (!! 追加 !!) --
        # Reshape: (B, CH, 1, T) -> (B, T, CH)
        x = x.squeeze(3).transpose(1, 2)

        x, _ = self.lstm6(x)
        x = self.dropout6(x)
        x, _ = self.lstm7(x)
        x = self.dropout7(x)

        # Reshape: (B, T, CH) -> (B, CH, T, 1)
        x = x.transpose(1, 2).unsqueeze(3) 
        
        # -- [3] 出力層 --
        x = self.out8(x)
        return x

# %% [markdown]
# ### 5-5: DeepConvLstm (ver.3)
#
# ver.2のLSTM層を，双方向 (時間の進む&戻る) の依存関係を考慮する設定に書き換えました．
# この変更により，注目した部分の行動の推定を，前の作業工程の情報だけでなく，これから起こる作業工程の情報も考慮して推定することができるようになります．

# %%
class DeepConvLstmV3(nn.Module):
    def __init__(self, in_ch: int = 3, num_classes: int = None):
        super().__init__()
        if num_classes is None:
            num_classes = len(OPENPACK_OPERATIONS)

        # -- [1] CNN (畳み込み層) --
        # *** Edit Here ***
        num_conv_layers = 4 # 使用する畳み込み層の数 (Default: 4)
        num_conv_filter = 64 # 各層の畳み込みフィルタの数 (Default: 64)
        ks = 5 # 畳み込みフィルタのサイズ; kernel size, 
        # ******************
        
        blocks = []
        for i in range(num_conv_layers):
            in_ch_ = in_ch if i == 0 else 64
            blocks.append(
                nn.Sequential(
                    nn.Conv2d(in_ch_, 64, kernel_size=(5, 1), padding=(2, 0)),
                    nn.BatchNorm2d(64),
                    nn.ReLU(),
                )
            )
        self.conv_blocks = nn.ModuleList(blocks)

        # -- [2] LSTM --
        # *** Edit Here ***        
        hidden_units = 128 # LSTM層の隠れニューロンの数
        # ******************
        
        # NOTE: bidirectionalをTrueに変更
        self.lstm6 = nn.LSTM(num_conv_filter, hidden_units, batch_first=True, bidirectional=True)
        self.lstm7 = nn.LSTM(hidden_units*2, hidden_units, batch_first=True,  bidirectional=True)
        self.dropout6 = nn.Dropout(p=0.5)
        self.dropout7 = nn.Dropout(p=0.5)

        # -- [3] 出力層 --
        self.out8 = nn.Conv2d(
            hidden_units * 2,
            num_classes,
            1,
            stride=1,
            padding=0,
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        Args:
            x (torch.Tensor): shape = (B, CH, T, 1)
        Returns:
            torch.Tensor: shape = (B, N_CLASSES, T, 1)
        """
        # -- [1] Conv --
        for block in self.conv_blocks:
            x = block(x)

        # -- [2] LSTM --
        # Reshape: (B, CH, 1, T) -> (B, T, CH)
        x = x.squeeze(3).transpose(1, 2)

        x, _ = self.lstm6(x)
        x = self.dropout6(x)
        x, _ = self.lstm7(x)
        x = self.dropout7(x)

        # Reshape: (B, T, CH) -> (B, CH, T, 1)
        x = x.transpose(1, 2).unsqueeze(3) 
        
        # -- [3] 出力層 --
        x = self.out8(x)
        return x

# %% [markdown]
# ## [6] モデルの学習

# %% [markdown]
# ### 6-1: DataModuleの定義
# データセットの読み込みと前処理を担当するモジュールを初期化します．編集なしで，そのまま実行してください．

# %%
class OpenPackImuDataModule(optorch.data.OpenPackBaseDataModule):
    dataset_class = optorch.data.datasets.OpenPackImu

    def get_kwargs_for_datasets(self, stage: Optional[str] = None) -> Dict:
        kwargs = {
            "window": self.cfg.train.window,
            "debug": self.cfg.debug,
        }
        return kwargs

# %% [markdown]
# ### 6-2: Lightning Moduleの定義 (編集必要!)
# 学習ループの監督を担当するモジュール．DeepConvLSTMを定義したセルを実行した後に実行します．
# `init_modeol()` メソッドの中で，実行したいモデルをコメントアウトしてください．

# %%
class MyModelLM(optorch.lightning.BaseLightningModule):

    def init_model(self, cfg: DictConfig) -> torch.nn.Module:
        """ モデルの初期化
        
        上で定義したモデル ``DeepConvLSTM()`` のインスタンスを生成する．
        実験したいモデルのコメントアウトを外してください．
        """
        # !! ここを編集 !!
        # NOTE: 実行したいモデルを選択
        model = DeepConvLstmV1()
        # model = DeepConvLstm()
        # model = DeepConvLstmV3()
        return model
    
    
    def init_criterion(self, cfg: DictConfig):
        """評価指標を定義する．
        """
        ignore_cls = [(i, c) for i, c in enumerate(cfg.dataset.classes) if c.is_ignore]
        
        criterion = torch.nn.CrossEntropyLoss(
            ignore_index=ignore_cls[-1][0]
        )
        return criterion

    def train_val_common_step(self, batch: Dict, batch_idx: int) -> Dict:
        """学習ループの定義． ミニバッチを受け取り，lossの計算までを記述．
        """
        x = batch["x"].to(device=self.device, dtype=torch.float)
        t = batch["t"].to(device=self.device, dtype=torch.long)
        y_hat = self(x).squeeze(3)

        loss = self.criterion(y_hat, t)
        acc = self.calc_accuracy(y_hat, t)
        return {"loss": loss, "acc": acc}

    def test_step(self, batch: Dict, batch_idx: int) -> Dict:
        """推論ループの定義．ミニバッチを受け取り，モデルの推論結果の出力を返す．
        推論結果はリストに保存.
        """
        x = batch["x"].to(device=self.device, dtype=torch.float)
        t = batch["t"].to(device=self.device, dtype=torch.long)
        ts_unix = batch["ts"]

        y_hat = self(x).squeeze(3)

        outputs = dict(t=t, y=y_hat, unixtime=ts_unix)
        self.test_step_outputs.append(outputs)
        return outputs

# %%
def plot_timeline(samples, t_idx, y_softmax, title_prefix=""):
    """モデルの出力結果のヒートマップを描画 """
    fig, ax0 = plt.subplots(1, 1, figsize=(20, 4))

    prob = y_softmax[slice(*samples)].transpose(1, 0, 2).reshape(11, -1)
    gt = t_idx[slice(*samples)].ravel()
    pred = prob.argmax(axis=0)
    
    print(f"prob={prob.shape} pred={pred.shape}, gt={gt.shape}")
    seq_len = prob.shape[1]

    # -- Prob --
    sns.heatmap(
        prob,
        vmin=0, vmax=1.0, cmap="viridis", cbar=False,
        ax=ax0
    )

    # -- Ground Truth --
    x = np.arange(seq_len)
    ax0.plot(
        x, gt + 0.5, label="ground truth",
        linewidth=5, color="C3", 
    )

    # -- Style --
    ax0.invert_yaxis()
    xticks = np.arange(0, seq_len, 30 * 30)
    xticks_minor = np.arange(0, seq_len, 30 * 10)
    ax0.set_xticks(xticks)
    ax0.set_xticklabels(xticks // 30 + samples[0] * 60, rotation=0)
    ax0.set_xticks(xticks_minor, minor=True)

    ax0.set_yticks(np.arange(11) + 0.5)
    ax0.set_yticklabels(np.arange(11), rotation=0)
    
    
    ax0.set_xlabel("Time [s]", fontsize="large", fontweight="bold")
    ax0.set_ylabel("Class Index", fontsize="large", fontweight="bold")
    ax0.set_title(f"{title_prefix} | {samples[0]}min ~ {samples[1]}min", fontsize="xx-large", fontweight="bold")
    ax0.grid(True, which="minor", linestyle=":")
    ax0.legend(loc="upper right")

    fig.tight_layout()
    return fig

# %% [markdown]
# ### 6-3: モデルの学習に必要なモジュールの初期化
# (1)モデル, (2) データセット, (3) Trainer を初期化します．

# %%
# 再現性を高めるためモデル初期化の直前にランダムシードの初期化を行う.
optorch.utils.reset_seed(seed=0)

device = torch.device("cuda")
logdir = Path(cfg.path.logdir.rootdir)
logger.debug(f"logdir = {logdir}")

datamodule = OpenPackImuDataModule(cfg) # (1) データセット
datamodule.setup()

plmodel = MyModelLM(cfg).to(dtype=torch.float, device=device) # (2) モデルの初期化
# Out:
# 2023-11-23 09:01:14 | INFO | openpack_torch.utils.random | Reset Seeds: python=0, numpy=0, Pytorch (cpu=0, cuda=0)
# 2023-11-23 09:01:16 | INFO | openpack_torch.data.datamodule | dataset[train]: OpenPackImu(index=533, num_sequence=15, submission=False, random_crop=True)
# 2023-11-23 09:01:16 | INFO | openpack_torch.data.datamodule | dataset[val]: {'U0106-S0200': <openpack_torch.data.datasets.OpenPackImu object at 0x7f079fcfa980>, 'U0106-S0400': <openpack_torch.data.datasets.OpenPackImu object at 0x7f079fb1b880>}
# 2023-11-23 09:01:16 | INFO | openpack_torch.data.datamodule | dataset[test]: {'U0106-S0100': <openpack_torch.data.datasets.OpenPackImu object at 0x7f079fb4cf70>, 'U0106-S0300': <openpack_torch.data.datasets.OpenPackImu object at 0x7f079fb7aa70>, 'U0106-S0500': <openpack_torch.data.datasets.OpenPackImu object at 0x7f079fbb7fd0>}
# 2023-11-23 09:01:16 | INFO | openpack_torch.data.datamodule | dataset[submission]: {'U0107-S0100': <openpack_torch.data.datasets.OpenPackImu object at 0x7f079fa18f10>, 'U0107-S0200': <openpack_torch.data.datasets.OpenPackImu object at 0x7f079fa526e0>, 'U0107-S0300': <openpack_torch.data.datasets.OpenPackImu object at 0x7f079fa8fdf0>, 'U0107-S0500': <openpack_torch.data.datasets.OpenPackImu object at 0x7f079faecc40>}

# %%
# NOTE: 学習させたいエポック数を指定
num_epoch = 50 

checkpoint_callback = pl.callbacks.ModelCheckpoint(
    save_top_k=0,
    save_last=True,
    monitor=None,
)
pl_logger = pl.loggers.CSVLogger(logdir)

trainer = pl.Trainer(
    accelerator="gpu",
    devices=1,
    max_epochs=num_epoch,
    logger=pl_logger,  # disable logging module
    default_root_dir=logdir,
    enable_progress_bar=True,  # disable progress bar
    enable_checkpointing=True,
    callbacks=[checkpoint_callback],
)
logger.debug(f"logdir = {logdir}")
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
# 初期化したモデルを表示
plmodel
# Out:
# MyModelLM(
#   (net): DeepConvLstmV1(
#     (conv_blocks): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#       (1-3): 3 x Sequential(
#         (0): Conv2d(64, 64, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#       )
#     )
#     (out8): Conv2d(64, 11, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (criterion): CrossEntropyLoss()
# )

# %% [markdown]
# ### 6-4: モデルの学習

# %% [markdown]
# #### 6-4-1: 学習前のモデルの出力の確認

# %%
outputs, df_summary = test_helper(cfg, "test", datamodule, plmodel, trainer)
# Out:
# 2023-11-23 09:01:25 | INFO | openpack_torch.utils.test_helper | test on U0106-S0100
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100% 7/7 [00:00<00:00, 52.47it/s]
# 2023-11-23 09:01:25 | INFO | openpack_torch.utils.test_helper | save t[shape=(50, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0100/t.npy
# 2023-11-23 09:01:25 | INFO | openpack_torch.utils.test_helper | save y[shape=(50, 11, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0100/y.npy
# 2023-11-23 09:01:25 | INFO | openpack_torch.utils.test_helper | save unixtime[shape=(50, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0100/unixtime.npy
# 2023-11-23 09:01:25 | INFO | openpack_torch.utils.test_helper | test on U0106-S0300
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100% 5/5 [00:00<00:00, 207.70it/s]
# 2023-11-23 09:01:25 | INFO | openpack_torch.utils.test_helper | save t[shape=(85, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0300/t.npy
# 2023-11-23 09:01:25 | INFO | openpack_torch.utils.test_helper | save y[shape=(85, 11, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0300/y.npy
# 2023-11-23 09:01:25 | INFO | openpack_torch.utils.test_helper | save unixtime[shape=(85, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0300/unixtime.npy
# 2023-11-23 09:01:25 | INFO | openpack_torch.utils.test_helper | test on U0106-S0500
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100% 3/3 [00:00<00:00, 148.53it/s]
# 2023-11-23 09:01:25 | INFO | openpack_torch.utils.test_helper | save t[shape=(103, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0500/t.npy
# 2023-11-23 09:01:25 | INFO | openpack_torch.utils.test_helper | save y[shape=(103, 11, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0500/y.npy
# 2023-11-23 09:01:25 | INFO | openpack_torch.utils.test_helper | save unixtime[shape=(103, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0500/unixtime.npy
# 2023-11-23 09:01:25 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | 1 elements are missing from prediction.: [1637895693000]
# 2023-11-23 09:01:25 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | fill missing element at ts=1637895693000 (ind=2946) with 200.
# 2023-11-23 09:01:25 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | 1 elements are missing from prediction.: [1637905740000]
# 2023-11-23 09:01:25 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | fill missing element at ts=1637905740000 (ind=2059) with 200.
# 2023-11-23 09:01:25 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | 1 elements are missing from prediction.: [1637911136000]
# 2023-11-23 09:01:25 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | fill missing element at ts=1637911136000 (ind=1030) with 200.
# 2023-11-23 09:01:25 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | 1 elements are missing from prediction.: [1637895693000]
# 2023-11-23 09:01:25 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | fill missing element at ts=1637895693000 (ind=2946) with 200.
# 2023-11-23 09:01:25 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | 1 elements are missing from prediction.: [1637905740000]
# 2023-11-23 09:01:25 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | fill missing element at ts=1637905740000 (ind=2059) with 200.
# 2023-11-23 09:01:25 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | 1 elements are missing from prediction.: [1637911136000]
# 2023-11-23 09:01:25 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | fill missing element at ts=1637911136000 (ind=1030) with 200.
# 2023-11-23 09:01:25 | INFO | openpack_torch.utils.test_helper | write df_summary[shape=(96, 8)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/summary/last/test.csv
# 2023-11-23 09:01:25 | INFO | openpack_torch.utils.test_helper | df_summary:
#                      name    id  precision    recall        f1 support          key scenario
# 0               avg/macro    -1   0.017238  0.100000  0.029407    None  U0106-S0100       S1
# 1            avg/weighted    -1   0.029714  0.172379  0.050691    None  U0106-S0100       S1
# 2                 Picking   100   0.000000  0.000000  0.000000     289  U0106-S0100       S1
# 3     Relocate Item Label   200   0.172379  1.000000  0.294067     508  U0106-S0100       S1
# 4            Assemble Box   300   0.000000  0.000000  0.000000     475  U0106-S0100       S1
# 5            Insert Items   400   0.000000  0.000000  0.000000     230  U0106-S0100       S1
# 6               Close Box   500   0.000000  0.000000  0.000000     334  U0106-S0100       S1
# 7        Attach Box Label   600   0.000000  0.000000  0.000000     182  U0106-S0100       S1
# 8              Scan Label   700   0.000000  0.000000  0.000000     306  U0106-S0100       S1
# 9   Attach Shipping Label   800   0.000000  0.000000  0.000000     232  U0106-S0100       S1
# 10      Put on Back Table   900   0.000000  0.000000  0.000000     152  U0106-S0100       S1
# 11         Fill out Order  1000   0.000000  0.000000  0.000000     239  U0106-S0100       S1
# 12              avg/macro    -1   0.013689  0.100000  0.024082    None  U0106-S0300       S1
# 13           avg/weighted    -1   0.018740  0.136893  0.032967    None  U0106-S0300       S1
# 14                Picking   100   0.000000  0.000000  0.000000     177  U0106-S0300       S1
# 15    Relocate Item Label   200   0.136893  1.000000  0.240820     282  U0106-S0300       S1
# 16           Assemble Box   300   0.000000  0.000000  0.000000     356  U0106-S0300       S1
# 17           Insert Items   400   0.000000  0.000000  0.000000     174  U0106-S0300       S1
# 18              Close Box   500   0.000000  0.000000  0.000000     223  U0106-S0300       S1
# 19       Attach Box Label   600   0.000000  0.000000  0.000000     128  U0106-S0300       S1
# 20             Scan Label   700   0.000000  0.000000  0.000000     255  U0106-S0300       S1
# 21  Attach Shipping Label   800   0.000000  0.000000  0.000000     155  U0106-S0300       S1
# 22      Put on Back Table   900   0.000000  0.000000  0.000000     141  U0106-S0300       S1
# 23         Fill out Order  1000   0.000000  0.000000  0.000000     169  U0106-S0300       S1
# 24              avg/macro    -1   0.014549  0.100000  0.025402    None  U0106-S0500       S1
# 25           avg/weighted    -1   0.021167  0.145490  0.036958    None  U0106-S0500       S1
# 26                Picking   100   0.000000  0.000000  0.000000      86  U0106-S0500       S1
# 27    Relocate Item Label   200   0.145490  1.000000  0.254022     150  U0106-S0500       S1
# 28           Assemble Box   300   0.000000  0.000000  0.000000     205  U0106-S0500       S1
# 29           Insert Items   400   0.000000  0.000000  0.000000      85  U0106-S0500       S1
# 30              Close Box   500   0.000000  0.000000  0.000000     109  U0106-S0500       S1
# 31       Attach Box Label   600   0.000000  0.000000  0.000000      46  U0106-S0500       S1
# 32             Scan Label   700   0.000000  0.000000  0.000000     119  U0106-S0500       S1
# 33  Attach Shipping Label   800   0.000000  0.000000  0.000000      75  U0106-S0500       S1
# 34      Put on Back Table   900   0.000000  0.000000  0.000000      69  U0106-S0500       S1
# 35         Fill out Order  1000   0.000000  0.000000  0.000000      87  U0106-S0500       S1
# 36              avg/macro    -1   0.015568  0.100000  0.026942    None          all       S1
# 37           avg/weighted    -1   0.024236  0.155681  0.041943    None          all       S1
# 38                Picking   100   0.000000  0.000000  0.000000     552          all       S1
# 39    Relocate Item Label   200   0.155681  1.000000  0.269418     940          all       S1
# 40           Assemble Box   300   0.000000  0.000000  0.000000    1036          all       S1
# 41           Insert Items   400   0.000000  0.000000  0.000000     489          all       S1
# 42              Close Box   500   0.000000  0.000000  0.000000     666          all       S1
# 43       Attach Box Label   600   0.000000  0.000000  0.000000     356          all       S1
# 44             Scan Label   700   0.000000  0.000000  0.000000     680          all       S1
# 45  Attach Shipping Label   800   0.000000  0.000000  0.000000     462          all       S1
# 46      Put on Back Table   900   0.000000  0.000000  0.000000     362          all       S1
# 47         Fill out Order  1000   0.000000  0.000000  0.000000     495          all       S1
# 0               avg/macro    -1   0.017238  0.100000  0.029407    None  U0106-S0100      all
# 1            avg/weighted    -1   0.029714  0.172379  0.050691    None  U0106-S0100      all
# 2                 Picking   100   0.000000  0.000000  0.000000     289  U0106-S0100      all
# 3     Relocate Item Label   200   0.172379  1.000000  0.294067     508  U0106-S0100      all
# 4            Assemble Box   300   0.000000  0.000000  0.000000     475  U0106-S0100      all
# 5            Insert Items   400   0.000000  0.000000  0.000000     230  U0106-S0100      all
# 6               Close Box   500   0.000000  0.000000  0.000000     334  U0106-S0100      all
# 7        Attach Box Label   600   0.000000  0.000000  0.000000     182  U0106-S0100      all
# 8              Scan Label   700   0.000000  0.000000  0.000000     306  U0106-S0100      all
# 9   Attach Shipping Label   800   0.000000  0.000000  0.000000     232  U0106-S0100      all
# 10      Put on Back Table   900   0.000000  0.000000  0.000000     152  U0106-S0100      all
# 11         Fill out Order  1000   0.000000  0.000000  0.000000     239  U0106-S0100      all
# 12              avg/macro    -1   0.013689  0.100000  0.024082    None  U0106-S0300      all
# 13           avg/weighted    -1   0.018740  0.136893  0.032967    None  U0106-S0300      all
# 14                Picking   100   0.000000  0.000000  0.000000     177  U0106-S0300      all
# 15    Relocate Item Label   200   0.136893  1.000000  0.240820     282  U0106-S0300      all
# 16           Assemble Box   300   0.000000  0.000000  0.000000     356  U0106-S0300      all
# 17           Insert Items   400   0.000000  0.000000  0.000000     174  U0106-S0300      all
# 18              Close Box   500   0.000000  0.000000  0.000000     223  U0106-S0300      all
# 19       Attach Box Label   600   0.000000  0.000000  0.000000     128  U0106-S0300      all
# 20             Scan Label   700   0.000000  0.000000  0.000000     255  U0106-S0300      all
# 21  Attach Shipping Label   800   0.000000  0.000000  0.000000     155  U0106-S0300      all
# 22      Put on Back Table   900   0.000000  0.000000  0.000000     141  U0106-S0300      all
# 23         Fill out Order  1000   0.000000  0.000000  0.000000     169  U0106-S0300      all
# 24              avg/macro    -1   0.014549  0.100000  0.025402    None  U0106-S0500      all
# 25           avg/weighted    -1   0.021167  0.145490  0.036958    None  U0106-S0500      all
# 26                Picking   100   0.000000  0.000000  0.000000      86  U0106-S0500      all
# 27    Relocate Item Label   200   0.145490  1.000000  0.254022     150  U0106-S0500      all
# 28           Assemble Box   300   0.000000  0.000000  0.000000     205  U0106-S0500      all
# 29           Insert Items   400   0.000000  0.000000  0.000000      85  U0106-S0500      all
# 30              Close Box   500   0.000000  0.000000  0.000000     109  U0106-S0500      all
# 31       Attach Box Label   600   0.000000  0.000000  0.000000      46  U0106-S0500      all
# 32             Scan Label   700   0.000000  0.000000  0.000000     119  U0106-S0500      all
# 33  Attach Shipping Label   800   0.000000  0.000000  0.000000      75  U0106-S0500      all
# 34      Put on Back Table   900   0.000000  0.000000  0.000000      69  U0106-S0500      all
# 35         Fill out Order  1000   0.000000  0.000000  0.000000      87  U0106-S0500      all
# 36              avg/macro    -1   0.015568  0.100000  0.026942    None          all      all
# 37           avg/weighted    -1   0.024236  0.155681  0.041943    None          all      all
# 38                Picking   100   0.000000  0.000000  0.000000     552          all      all
# 39    Relocate Item Label   200   0.155681  1.000000  0.269418     940          all      all
# 40           Assemble Box   300   0.000000  0.000000  0.000000    1036          all      all
# 41           Insert Items   400   0.000000  0.000000  0.000000     489          all      all
# 42              Close Box   500   0.000000  0.000000  0.000000     666          all      all
# 43       Attach Box Label   600   0.000000  0.000000  0.000000     356          all      all
# 44             Scan Label   700   0.000000  0.000000  0.000000     680          all      all
# 45  Attach Shipping Label   800   0.000000  0.000000  0.000000     462          all      all
# 46      Put on Back Table   900   0.000000  0.000000  0.000000     362          all      all
# 47         Fill out Order  1000   0.000000  0.000000  0.000000     495          all      all

# %%
df_summary[df_summary["key"]=="all"]
# Out:
#                      name    id  precision    recall        f1 support  key scenario
# 36              avg/macro    -1   0.015568  0.100000  0.026942    None  all       S1
# 37           avg/weighted    -1   0.024236  0.155681  0.041943    None  all       S1
# 38                Picking   100   0.000000  0.000000  0.000000     552  all       S1
# 39    Relocate Item Label   200   0.155681  1.000000  0.269418     940  all       S1
# 40           Assemble Box   300   0.000000  0.000000  0.000000    1036  all       S1
# 41           Insert Items   400   0.000000  0.000000  0.000000     489  all       S1
# 42              Close Box   500   0.000000  0.000000  0.000000     666  all       S1
# 43       Attach Box Label   600   0.000000  0.000000  0.000000     356  all       S1
# 44             Scan Label   700   0.000000  0.000000  0.000000     680  all       S1
# 45  Attach Shipping Label   800   0.000000  0.000000  0.000000     462  all       S1
# 46      Put on Back Table   900   0.000000  0.000000  0.000000     362  all       S1
# 47         Fill out Order  1000   0.000000  0.000000  0.000000     495  all       S1
# 36              avg/macro    -1   0.015568  0.100000  0.026942    None  all      all
# 37           avg/weighted    -1   0.024236  0.155681  0.041943    None  all      all
# 38                Picking   100   0.000000  0.000000  0.000000     552  all      all
# 39    Relocate Item Label   200   0.155681  1.000000  0.269418     940  all      all
# 40           Assemble Box   300   0.000000  0.000000  0.000000    1036  all      all
# 41           Insert Items   400   0.000000  0.000000  0.000000     489  all      all
# 42              Close Box   500   0.000000  0.000000  0.000000     666  all      all
# 43       Attach Box Label   600   0.000000  0.000000  0.000000     356  all      all
# 44             Scan Label   700   0.000000  0.000000  0.000000     680  all      all
# 45  Attach Shipping Label   800   0.000000  0.000000  0.000000     462  all      all
# 46      Put on Back Table   900   0.000000  0.000000  0.000000     362  all      all
# 47         Fill out Order  1000   0.000000  0.000000  0.000000     495  all      all

# %%
# 可視化したいセグメント
key = "U0106-S0500"

# 予測結果の取得
unixtimes = outputs[key]["unixtime"] 
t_idx = outputs[key]["t_idx"]
y = outputs[key]["y"]
y_softmax = softmax(y, axis=1)
print(f"unixtimes={unixtimes.shape}, t_idx={t_idx.shape}, y={y.shape}, y_softmax={y_softmax.shape}")
# Out:
# unixtimes=(103, 1800), t_idx=(103, 1800), y=(103, 11, 1800), y_softmax=(103, 11, 1800)

# %%
samples = (0, 10)

fig = plot_timeline(samples, t_idx, y_softmax, title_prefix=f"{cfg.model.name} | {key}")
fig.show()
# Out:
# prob=(11, 18000) pred=(18000,), gt=(18000,)

# %% [markdown]
# ヒートマップの見方:
#
# - 赤いライン: 正解ラベル
# - 背景: 予測確率 (確率が高いところは黄色く表示される． 学習前はランダムな値しか出していないので，どのクラスも予測確率は低い.)
# - 横軸: 時間
# - 縦軸: 行動クラスのインデックス (1 = Picking[ID100], 2=Relocate Label[ID=200], ...)
#
# ぜひ学習前のこの結果を覚えておいて頂き，学習後の結果と比較してみてください．

# %% [markdown]
# #### 6-4-2: 学習

# %%
logger.info(f"Start training for {num_epoch} epochs.")
trainer.fit(plmodel, datamodule)
logger.info("Finish training!")
# Out:
# 2023-11-23 09:01:38 | INFO | __main__ | Start training for 50 epochs.
# 2023-11-23 09:01:39 | INFO | openpack_torch.data.datamodule | dataset[train]: OpenPackImu(index=533, num_sequence=15, submission=False, random_crop=True)
# 2023-11-23 09:01:39 | INFO | openpack_torch.data.datamodule | dataset[val]: {'U0106-S0200': <openpack_torch.data.datasets.OpenPackImu object at 0x7f079fc9fca0>, 'U0106-S0400': <openpack_torch.data.datasets.OpenPackImu object at 0x7f06cc73e1d0>}
# 2023-11-23 09:01:39 | INFO | openpack_torch.data.datamodule | dataset[test]: None
# 2023-11-23 09:01:39 | INFO | openpack_torch.data.datamodule | dataset[submission]: None
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2023-11-23 09:01:39 | INFO | openpack_torch.lightning | Adam optimizer is selected! (lr=0.001)
# 2023-11-23 09:01:39 | INFO | openpack_torch.lightning | StepLR scheduler is selected.
#
#   | Name      | Type             | Params
# -----------------------------------------------
# 0 | net       | DeepConvLstmV1   | 63.9 K
# 1 | criterion | CrossEntropyLoss | 0
# -----------------------------------------------
# 63.9 K    Trainable params
# 0         Non-trainable params
# 63.9 K    Total params
# 0.256     Total estimated model params size (MB)
# Epoch 0: 100% 67/67 [00:00<00:00, 114.84it/s, v_num=3]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 129.37it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 142.47it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 148.75it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 163.77it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 161.29it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 137.55it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 142.26it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 164.93it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 179.73it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 183.96it/s]
# Epoch 1: 100% 67/67 [00:00<00:00, 124.94it/s, v_num=3, val/loss/dataloader_idx_0=2.030, val/acc/dataloader_idx_0=0.254, val/loss/dataloader_idx_1=1.990, val/acc/dataloader_idx_1=0.270, train/loss=1.940, train/acc=0.314]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 150.54it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 182.22it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 173.41it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 187.75it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 198.69it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 135.95it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 149.63it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 171.95it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 185.90it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 189.60it/s]
# Epoch 2: 100% 67/67 [00:00<00:00, 125.49it/s, v_num=3, val/loss/dataloader_idx_0=1.970, val/acc/dataloader_idx_0=0.285, val/loss/dataloader_idx_1=2.020, val/acc/dataloader_idx_1=0.273, train/loss=1.720, train/acc=0.365]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 144.91it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 145.94it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 168.62it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 184.13it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 188.64it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 134.53it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 147.15it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 153.38it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 169.02it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 181.59it/s]
# Epoch 3: 100% 67/67 [00:00<00:00, 125.86it/s, v_num=3, val/loss/dataloader_idx_0=2.050, val/acc/dataloader_idx_0=0.270, val/loss/dataloader_idx_1=2.040, val/acc/dataloader_idx_1=0.282, train/loss=1.660, train/acc=0.383]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 152.33it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 164.63it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 159.78it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 174.90it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 187.97it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 135.27it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 172.78it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 169.31it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 183.66it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 195.14it/s]
# Epoch 4: 100% 67/67 [00:00<00:00, 129.81it/s, v_num=3, val/loss/dataloader_idx_0=2.040, val/acc/dataloader_idx_0=0.282, val/loss/dataloader_idx_1=2.050, val/acc/dataloader_idx_1=0.276, train/loss=1.630, train/acc=0.395]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 150.02it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 182.78it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 177.49it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 190.28it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 201.64it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 127.38it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 142.84it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 151.31it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 166.75it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 178.74it/s]
# Epoch 5: 100% 67/67 [00:00<00:00, 125.59it/s, v_num=3, val/loss/dataloader_idx_0=1.840, val/acc/dataloader_idx_0=0.316, val/loss/dataloader_idx_1=1.850, val/acc/dataloader_idx_1=0.281, train/loss=1.590, train/acc=0.407]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 150.08it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 155.72it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 161.89it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 176.91it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 187.52it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 136.87it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 159.32it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 161.84it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 169.37it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 180.10it/s]
# Epoch 6: 100% 67/67 [00:00<00:00, 125.52it/s, v_num=3, val/loss/dataloader_idx_0=1.950, val/acc/dataloader_idx_0=0.299, val/loss/dataloader_idx_1=1.910, val/acc/dataloader_idx_1=0.319, train/loss=1.560, train/acc=0.413]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 147.01it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 177.65it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 194.29it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 194.14it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 204.12it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 132.85it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 147.99it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 155.43it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 170.95it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 183.40it/s]
# Epoch 7: 100% 67/67 [00:00<00:00, 124.92it/s, v_num=3, val/loss/dataloader_idx_0=1.830, val/acc/dataloader_idx_0=0.326, val/loss/dataloader_idx_1=1.820, val/acc/dataloader_idx_1=0.344, train/loss=1.540, train/acc=0.423]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 152.26it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 184.54it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 179.08it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 190.25it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 201.70it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 132.44it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 145.51it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 152.50it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 168.59it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 181.47it/s]
# Epoch 8: 100% 67/67 [00:00<00:00, 129.35it/s, v_num=3, val/loss/dataloader_idx_0=1.860, val/acc/dataloader_idx_0=0.324, val/loss/dataloader_idx_1=1.870, val/acc/dataloader_idx_1=0.337, train/loss=1.530, train/acc=0.422]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 145.51it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 149.55it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 155.63it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 169.90it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 182.42it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 133.58it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 145.90it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 151.59it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 167.47it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 179.68it/s]
# Epoch 9: 100% 67/67 [00:00<00:00, 125.36it/s, v_num=3, val/loss/dataloader_idx_0=2.410, val/acc/dataloader_idx_0=0.242, val/loss/dataloader_idx_1=2.350, val/acc/dataloader_idx_1=0.242, train/loss=1.510, train/acc=0.434]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 145.66it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 152.55it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 154.46it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 169.18it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 181.28it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 133.17it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 169.68it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 163.15it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 177.82it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 189.14it/s]
# Epoch 10: 100% 67/67 [00:00<00:00, 125.20it/s, v_num=3, val/loss/dataloader_idx_0=1.930, val/acc/dataloader_idx_0=0.332, val/loss/dataloader_idx_1=1.920, val/acc/dataloader_idx_1=0.312, train/loss=1.490, train/acc=0.446]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 155.59it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 187.62it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 177.34it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 191.99it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 202.04it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 136.68it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 145.23it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 151.67it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 168.23it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 180.53it/s]
# Epoch 11: 100% 67/67 [00:00<00:00, 128.04it/s, v_num=3, val/loss/dataloader_idx_0=1.980, val/acc/dataloader_idx_0=0.292, val/loss/dataloader_idx_1=1.990, val/acc/dataloader_idx_1=0.275, train/loss=1.480, train/acc=0.448]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 119.33it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 136.67it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 146.21it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 162.04it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 175.41it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 134.81it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 140.42it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 162.34it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 176.51it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 180.80it/s]
# Epoch 12: 100% 67/67 [00:00<00:00, 128.04it/s, v_num=3, val/loss/dataloader_idx_0=1.760, val/acc/dataloader_idx_0=0.340, val/loss/dataloader_idx_1=1.700, val/acc/dataloader_idx_1=0.360, train/loss=1.460, train/acc=0.455]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 138.88it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 173.45it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 172.03it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 184.71it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 195.85it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 130.38it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 155.29it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 152.95it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 168.51it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 181.53it/s]
# Epoch 13: 100% 67/67 [00:00<00:00, 127.99it/s, v_num=3, val/loss/dataloader_idx_0=1.840, val/acc/dataloader_idx_0=0.354, val/loss/dataloader_idx_1=1.820, val/acc/dataloader_idx_1=0.356, train/loss=1.450, train/acc=0.455]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 144.49it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 176.93it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 173.63it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 186.53it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 198.89it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 131.77it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 168.21it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 162.56it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 176.81it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 186.21it/s]
# Epoch 14: 100% 67/67 [00:00<00:00, 127.10it/s, v_num=3, val/loss/dataloader_idx_0=2.140, val/acc/dataloader_idx_0=0.273, val/loss/dataloader_idx_1=2.260, val/acc/dataloader_idx_1=0.247, train/loss=1.430, train/acc=0.469]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 135.09it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 171.77it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 167.15it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 179.95it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 190.76it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 138.65it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 173.15it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 165.60it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 179.77it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 191.10it/s]
# Epoch 15: 100% 67/67 [00:00<00:00, 125.91it/s, v_num=3, val/loss/dataloader_idx_0=2.000, val/acc/dataloader_idx_0=0.320, val/loss/dataloader_idx_1=2.060, val/acc/dataloader_idx_1=0.304, train/loss=1.430, train/acc=0.470]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 143.75it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 149.39it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 155.88it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 172.05it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 184.43it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 129.98it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 138.79it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 161.76it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 177.12it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 182.54it/s]
# Epoch 16: 100% 67/67 [00:00<00:00, 124.75it/s, v_num=3, val/loss/dataloader_idx_0=1.860, val/acc/dataloader_idx_0=0.320, val/loss/dataloader_idx_1=1.880, val/acc/dataloader_idx_1=0.317, train/loss=1.430, train/acc=0.468]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 142.88it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 178.25it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 174.40it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 188.43it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 199.53it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 135.83it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 148.91it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 153.14it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 168.44it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 180.68it/s]
# Epoch 17: 100% 67/67 [00:00<00:00, 125.66it/s, v_num=3, val/loss/dataloader_idx_0=2.260, val/acc/dataloader_idx_0=0.249, val/loss/dataloader_idx_1=2.180, val/acc/dataloader_idx_1=0.245, train/loss=1.420, train/acc=0.475]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 149.19it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 155.58it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 175.78it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 189.59it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 192.00it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 131.08it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 147.87it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 153.96it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 169.59it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 181.68it/s]
# Epoch 18: 100% 67/67 [00:00<00:00, 126.13it/s, v_num=3, val/loss/dataloader_idx_0=2.130, val/acc/dataloader_idx_0=0.286, val/loss/dataloader_idx_1=2.170, val/acc/dataloader_idx_1=0.261, train/loss=1.410, train/acc=0.476]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 150.04it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 155.46it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 156.52it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 171.80it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 183.60it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 135.87it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 149.98it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 157.33it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 172.31it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 184.27it/s]
# Epoch 19: 100% 67/67 [00:00<00:00, 127.11it/s, v_num=3, val/loss/dataloader_idx_0=1.790, val/acc/dataloader_idx_0=0.357, val/loss/dataloader_idx_1=1.880, val/acc/dataloader_idx_1=0.341, train/loss=1.390, train/acc=0.484]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 144.62it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 153.72it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 159.90it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 174.59it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 187.23it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 128.52it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 165.72it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 165.82it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 179.05it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 190.68it/s]
# Epoch 20: 100% 67/67 [00:00<00:00, 125.31it/s, v_num=3, val/loss/dataloader_idx_0=1.880, val/acc/dataloader_idx_0=0.330, val/loss/dataloader_idx_1=1.910, val/acc/dataloader_idx_1=0.331, train/loss=1.390, train/acc=0.483]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 145.49it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 180.61it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 169.57it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 183.03it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 195.02it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 128.77it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 144.80it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 150.47it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 165.88it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 178.60it/s]
# Epoch 21: 100% 67/67 [00:00<00:00, 128.16it/s, v_num=3, val/loss/dataloader_idx_0=1.900, val/acc/dataloader_idx_0=0.332, val/loss/dataloader_idx_1=1.920, val/acc/dataloader_idx_1=0.313, train/loss=1.390, train/acc=0.484]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 156.35it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 159.99it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 161.86it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 175.85it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 188.17it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 137.66it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 148.68it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 155.79it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 171.78it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 184.10it/s]
# Epoch 22: 100% 67/67 [00:00<00:00, 124.52it/s, v_num=3, val/loss/dataloader_idx_0=2.230, val/acc/dataloader_idx_0=0.298, val/loss/dataloader_idx_1=2.220, val/acc/dataloader_idx_1=0.288, train/loss=1.380, train/acc=0.482]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 147.13it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 154.22it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 158.65it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 173.75it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 185.55it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 125.32it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 158.60it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 162.01it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 176.55it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 188.61it/s]
# Epoch 23: 100% 67/67 [00:00<00:00, 124.14it/s, v_num=3, val/loss/dataloader_idx_0=2.690, val/acc/dataloader_idx_0=0.247, val/loss/dataloader_idx_1=2.650, val/acc/dataloader_idx_1=0.240, train/loss=1.370, train/acc=0.485]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 137.53it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 145.71it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 153.58it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 168.78it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 180.28it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 134.65it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 148.30it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 156.01it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 172.44it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 185.35it/s]
# Epoch 24: 100% 67/67 [00:00<00:00, 128.42it/s, v_num=3, val/loss/dataloader_idx_0=2.120, val/acc/dataloader_idx_0=0.296, val/loss/dataloader_idx_1=2.170, val/acc/dataloader_idx_1=0.293, train/loss=1.370, train/acc=0.490]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 148.94it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 152.41it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 157.27it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 171.52it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 184.46it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 135.39it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 171.55it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 190.24it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 192.29it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 201.24it/s]
# Epoch 25: 100% 67/67 [00:00<00:00, 125.46it/s, v_num=3, val/loss/dataloader_idx_0=1.840, val/acc/dataloader_idx_0=0.359, val/loss/dataloader_idx_1=1.930, val/acc/dataloader_idx_1=0.338, train/loss=1.350, train/acc=0.500]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 148.12it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 183.25it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 179.37it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 192.96it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 203.06it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 133.52it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 147.33it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 154.68it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 169.65it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 181.73it/s]
# Epoch 26: 100% 67/67 [00:00<00:00, 128.19it/s, v_num=3, val/loss/dataloader_idx_0=1.910, val/acc/dataloader_idx_0=0.330, val/loss/dataloader_idx_1=1.960, val/acc/dataloader_idx_1=0.312, train/loss=1.380, train/acc=0.486]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 144.15it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 146.23it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 150.51it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 165.87it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 178.95it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 133.27it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 144.30it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 152.11it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 167.17it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 179.09it/s]
# Epoch 27: 100% 67/67 [00:00<00:00, 128.35it/s, v_num=3, val/loss/dataloader_idx_0=1.740, val/acc/dataloader_idx_0=0.387, val/loss/dataloader_idx_1=1.800, val/acc/dataloader_idx_1=0.360, train/loss=1.360, train/acc=0.501]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 149.65it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 181.98it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 175.97it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 189.24it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 200.01it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 135.11it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 172.51it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 171.75it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 186.43it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 197.98it/s]
# Epoch 28: 100% 67/67 [00:00<00:00, 128.97it/s, v_num=3, val/loss/dataloader_idx_0=1.930, val/acc/dataloader_idx_0=0.313, val/loss/dataloader_idx_1=1.930, val/acc/dataloader_idx_1=0.314, train/loss=1.350, train/acc=0.495]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 145.59it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 173.85it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 165.05it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 178.35it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 189.87it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 128.71it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 151.39it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 150.09it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 165.87it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 178.25it/s]
# Epoch 29: 100% 67/67 [00:00<00:00, 125.85it/s, v_num=3, val/loss/dataloader_idx_0=2.290, val/acc/dataloader_idx_0=0.281, val/loss/dataloader_idx_1=2.380, val/acc/dataloader_idx_1=0.256, train/loss=1.350, train/acc=0.499]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 144.32it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 179.37it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 176.30it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 189.43it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 199.56it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 136.67it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 147.08it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 151.80it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 167.34it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 180.15it/s]
# Epoch 30: 100% 67/67 [00:00<00:00, 126.47it/s, v_num=3, val/loss/dataloader_idx_0=1.900, val/acc/dataloader_idx_0=0.347, val/loss/dataloader_idx_1=1.840, val/acc/dataloader_idx_1=0.326, train/loss=1.340, train/acc=0.503]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 147.18it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 179.10it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 167.18it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 178.63it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 190.48it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 132.68it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 172.12it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 170.62it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 185.50it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 196.16it/s]
# Epoch 31: 100% 67/67 [00:00<00:00, 128.18it/s, v_num=3, val/loss/dataloader_idx_0=1.920, val/acc/dataloader_idx_0=0.343, val/loss/dataloader_idx_1=2.010, val/acc/dataloader_idx_1=0.313, train/loss=1.340, train/acc=0.502]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 151.33it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 154.43it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 175.75it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 173.55it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 185.60it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 135.06it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 145.78it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 149.58it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 165.65it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 178.50it/s]
# Epoch 32: 100% 67/67 [00:00<00:00, 124.85it/s, v_num=3, val/loss/dataloader_idx_0=2.180, val/acc/dataloader_idx_0=0.305, val/loss/dataloader_idx_1=2.010, val/acc/dataloader_idx_1=0.286, train/loss=1.320, train/acc=0.506]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 144.59it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 150.79it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 160.02it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 174.46it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 180.85it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 134.14it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 147.91it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 152.14it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 167.44it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 179.26it/s]
# Epoch 33: 100% 67/67 [00:00<00:00, 125.09it/s, v_num=3, val/loss/dataloader_idx_0=1.860, val/acc/dataloader_idx_0=0.328, val/loss/dataloader_idx_1=1.910, val/acc/dataloader_idx_1=0.332, train/loss=1.330, train/acc=0.508]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 146.66it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 150.15it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 155.02it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 171.05it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 183.48it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 134.10it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 147.18it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 153.16it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 167.45it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 179.59it/s]
# Epoch 34: 100% 67/67 [00:00<00:00, 124.15it/s, v_num=3, val/loss/dataloader_idx_0=1.720, val/acc/dataloader_idx_0=0.386, val/loss/dataloader_idx_1=1.780, val/acc/dataloader_idx_1=0.355, train/loss=1.300, train/acc=0.517]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 143.25it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 177.10it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 194.62it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 195.48it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 205.47it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 130.61it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 141.86it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 149.93it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 165.49it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 177.50it/s]
# Epoch 35: 100% 67/67 [00:00<00:00, 126.41it/s, v_num=3, val/loss/dataloader_idx_0=2.450, val/acc/dataloader_idx_0=0.266, val/loss/dataloader_idx_1=2.380, val/acc/dataloader_idx_1=0.259, train/loss=1.310, train/acc=0.515]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 122.98it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 160.19it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 163.31it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 177.59it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 189.27it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 128.55it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 166.75it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 187.33it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 189.27it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 199.18it/s]
# Epoch 36: 100% 67/67 [00:00<00:00, 124.39it/s, v_num=3, val/loss/dataloader_idx_0=1.880, val/acc/dataloader_idx_0=0.328, val/loss/dataloader_idx_1=1.840, val/acc/dataloader_idx_1=0.335, train/loss=1.310, train/acc=0.514]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 149.12it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 157.33it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 160.64it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 176.01it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 187.46it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 136.94it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 173.86it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 171.35it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 184.77it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 196.17it/s]
# Epoch 37: 100% 67/67 [00:00<00:00, 128.65it/s, v_num=3, val/loss/dataloader_idx_0=1.850, val/acc/dataloader_idx_0=0.359, val/loss/dataloader_idx_1=1.900, val/acc/dataloader_idx_1=0.331, train/loss=1.300, train/acc=0.523]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 151.12it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 156.40it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 160.46it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 174.70it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 186.54it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 131.09it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 156.20it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 153.31it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 168.56it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 181.04it/s]
# Epoch 38: 100% 67/67 [00:00<00:00, 126.48it/s, v_num=3, val/loss/dataloader_idx_0=2.070, val/acc/dataloader_idx_0=0.311, val/loss/dataloader_idx_1=2.150, val/acc/dataloader_idx_1=0.299, train/loss=1.310, train/acc=0.512]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 143.91it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 179.45it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 165.77it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 178.52it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 190.39it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 124.07it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 144.45it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 153.28it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 168.05it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 180.39it/s]
# Epoch 39: 100% 67/67 [00:00<00:00, 127.17it/s, v_num=3, val/loss/dataloader_idx_0=2.110, val/acc/dataloader_idx_0=0.293, val/loss/dataloader_idx_1=2.100, val/acc/dataloader_idx_1=0.287, train/loss=1.310, train/acc=0.517]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 146.66it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 155.58it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 157.88it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 172.33it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 185.12it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 134.75it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 149.91it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 156.03it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 171.64it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 183.81it/s]
# Epoch 40: 100% 67/67 [00:00<00:00, 124.41it/s, v_num=3, val/loss/dataloader_idx_0=1.800, val/acc/dataloader_idx_0=0.356, val/loss/dataloader_idx_1=1.870, val/acc/dataloader_idx_1=0.337, train/loss=1.300, train/acc=0.522]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 146.90it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 156.65it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 163.00it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 178.63it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 190.01it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 136.57it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 172.36it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 170.02it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 183.72it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 194.40it/s]
# Epoch 41: 100% 67/67 [00:00<00:00, 123.52it/s, v_num=3, val/loss/dataloader_idx_0=2.350, val/acc/dataloader_idx_0=0.291, val/loss/dataloader_idx_1=2.450, val/acc/dataloader_idx_1=0.276, train/loss=1.290, train/acc=0.523]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 142.73it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 151.21it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 158.37it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 173.87it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 186.36it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 134.70it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 156.60it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 151.17it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 167.12it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 179.75it/s]
# Epoch 42: 100% 67/67 [00:00<00:00, 127.88it/s, v_num=3, val/loss/dataloader_idx_0=1.960, val/acc/dataloader_idx_0=0.347, val/loss/dataloader_idx_1=1.900, val/acc/dataloader_idx_1=0.345, train/loss=1.290, train/acc=0.524]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 151.15it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 156.46it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 161.87it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 175.56it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 187.41it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 136.91it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 172.88it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 170.58it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 185.48it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 196.74it/s]
# Epoch 43: 100% 67/67 [00:00<00:00, 128.56it/s, v_num=3, val/loss/dataloader_idx_0=2.250, val/acc/dataloader_idx_0=0.319, val/loss/dataloader_idx_1=2.260, val/acc/dataloader_idx_1=0.303, train/loss=1.290, train/acc=0.525]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 145.15it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 148.46it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 155.40it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 169.49it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 181.34it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 132.68it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 145.77it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 166.23it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 180.90it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 184.21it/s]
# Epoch 44: 100% 67/67 [00:00<00:00, 128.33it/s, v_num=3, val/loss/dataloader_idx_0=1.840, val/acc/dataloader_idx_0=0.378, val/loss/dataloader_idx_1=1.900, val/acc/dataloader_idx_1=0.340, train/loss=1.290, train/acc=0.525]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 147.11it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 156.12it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 160.28it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 174.82it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 187.47it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 135.81it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 144.84it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 151.86it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 167.30it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 179.79it/s]
# Epoch 45: 100% 67/67 [00:00<00:00, 129.26it/s, v_num=3, val/loss/dataloader_idx_0=2.500, val/acc/dataloader_idx_0=0.290, val/loss/dataloader_idx_1=2.340, val/acc/dataloader_idx_1=0.289, train/loss=1.300, train/acc=0.520]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 140.20it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 175.27it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 172.24it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 184.67it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 197.29it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 133.61it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 171.61it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 168.91it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 182.55it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 192.76it/s]
# Epoch 46: 100% 67/67 [00:00<00:00, 125.27it/s, v_num=3, val/loss/dataloader_idx_0=2.020, val/acc/dataloader_idx_0=0.335, val/loss/dataloader_idx_1=1.830, val/acc/dataloader_idx_1=0.347, train/loss=1.280, train/acc=0.528]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 151.48it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 183.86it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 177.64it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 191.96it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 203.25it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 135.94it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 171.21it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 170.61it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 184.37it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 195.55it/s]
# Epoch 47: 100% 67/67 [00:00<00:00, 126.61it/s, v_num=3, val/loss/dataloader_idx_0=1.870, val/acc/dataloader_idx_0=0.354, val/loss/dataloader_idx_1=1.900, val/acc/dataloader_idx_1=0.343, train/loss=1.280, train/acc=0.528]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 145.04it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 179.57it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 176.29it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 189.11it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 200.41it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 135.02it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 155.41it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 177.68it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 183.49it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 188.09it/s]
# Epoch 48: 100% 67/67 [00:00<00:00, 125.84it/s, v_num=3, val/loss/dataloader_idx_0=2.120, val/acc/dataloader_idx_0=0.338, val/loss/dataloader_idx_1=2.230, val/acc/dataloader_idx_1=0.288, train/loss=1.260, train/acc=0.534]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 147.65it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 163.76it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 160.99it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 176.33it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 187.89it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 135.63it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 148.60it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 155.25it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 169.02it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 181.68it/s]
# Epoch 49: 100% 67/67 [00:00<00:00, 128.66it/s, v_num=3, val/loss/dataloader_idx_0=1.890, val/acc/dataloader_idx_0=0.349, val/loss/dataloader_idx_1=1.930, val/acc/dataloader_idx_1=0.340, train/loss=1.290, train/acc=0.523]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20% 1/5 [00:00<00:00, 107.70it/s]
# Validation DataLoader 0:  40% 2/5 [00:00<00:00, 136.94it/s]
# Validation DataLoader 0:  60% 3/5 [00:00<00:00, 142.14it/s]
# Validation DataLoader 0:  80% 4/5 [00:00<00:00, 158.81it/s]
# Validation DataLoader 0: 100% 5/5 [00:00<00:00, 171.64it/s]
# Validation DataLoader 0:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:   0% 0/5 [00:00<?, ?it/s]
# Validation DataLoader 1:  20% 1/5 [00:00<00:00, 131.60it/s]
# Validation DataLoader 1:  40% 2/5 [00:00<00:00, 168.58it/s]
# Validation DataLoader 1:  60% 3/5 [00:00<00:00, 162.21it/s]
# Validation DataLoader 1:  80% 4/5 [00:00<00:00, 177.52it/s]
# Validation DataLoader 1: 100% 5/5 [00:00<00:00, 189.06it/s]
# Epoch 49: 100% 67/67 [00:00<00:00, 93.86it/s, v_num=3, val/loss/dataloader_idx_0=2.160, val/acc/dataloader_idx_0=0.265, val/loss/dataloader_idx_1=2.140, val/acc/dataloader_idx_1=0.270, train/loss=1.280, train/acc=0.528]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 49: 100% 67/67 [00:00<00:00, 92.64it/s, v_num=3, val/loss/dataloader_idx_0=2.160, val/acc/dataloader_idx_0=0.265, val/loss/dataloader_idx_1=2.140, val/acc/dataloader_idx_1=0.270, train/loss=1.280, train/acc=0.528]
# 2023-11-23 09:02:17 | INFO | __main__ | Finish training!

# %% [markdown]
# #### 6-4-5: 学習曲線の表示
#
# モデルの学習がうまく行っているか確認するために，epochごとのlossの変化をプロットします．
# lossがepochが進むにつれて徐々に下がっていくことを確認してください．

# %% [markdown]
# Training Log

# %%
pl_logdir = Path(cfg.path.logdir.rootdir, "lightning_logs/")
latest_logdir = list(sorted(pl_logdir.iterdir()))[-1]

df = pd.read_csv(Path(latest_logdir, "metrics.csv"))
df["phase"] = df["train/loss"].apply(lambda x: "val" if np.isnan(x) else "train")
df = df.set_index(["epoch", "phase"])

# %%
df.head()
# Out:
#              step  val/loss/dataloader_idx_0  val/acc/dataloader_idx_0  val/loss/dataloader_idx_1  val/acc/dataloader_idx_1  train/loss  train/acc
# epoch phase
# 0     val      66                   2.025096                  0.253726                   1.988147                  0.269564         NaN        NaN
#       train    66                        NaN                       NaN                        NaN                       NaN    1.942780   0.313548
# 1     val     133                   1.968024                  0.285152                   2.017458                  0.272831         NaN        NaN
#       train   133                        NaN                       NaN                        NaN                       NaN    1.723472   0.364819
# 2     val     200                   2.052789                  0.270372                   2.039351                  0.281570         NaN        NaN

# %%
df.xs("train", level="phase")[["train/loss"]].plot()
plt.show()

# %%
df.xs("train", level="phase")[["train/acc"]].plot()
plt.show()

# %% [markdown]
# ### 6-5: 評価

# %%
# テストデータで評価
plmodel.clear_test_outputs()
datamodule.setup("test")

outputs, df_summary = test_helper(cfg, "test", datamodule, plmodel, trainer)
# Out:
# 2023-11-23 09:04:30 | INFO | openpack_torch.data.datamodule | dataset[train]: None
# 2023-11-23 09:04:30 | INFO | openpack_torch.data.datamodule | dataset[val]: None
# 2023-11-23 09:04:30 | INFO | openpack_torch.data.datamodule | dataset[test]: {'U0106-S0100': <openpack_torch.data.datasets.OpenPackImu object at 0x7f06920de0b0>, 'U0106-S0300': <openpack_torch.data.datasets.OpenPackImu object at 0x7f0691f0ef80>, 'U0106-S0500': <openpack_torch.data.datasets.OpenPackImu object at 0x7f0691f64520>}
# 2023-11-23 09:04:30 | INFO | openpack_torch.data.datamodule | dataset[submission]: None
# 2023-11-23 09:04:30 | INFO | openpack_torch.utils.test_helper | test on U0106-S0100
# 2023-11-23 09:04:31 | INFO | openpack_torch.data.datamodule | dataset[train]: None
# 2023-11-23 09:04:31 | INFO | openpack_torch.data.datamodule | dataset[val]: None
# 2023-11-23 09:04:31 | INFO | openpack_torch.data.datamodule | dataset[test]: {'U0106-S0100': <openpack_torch.data.datasets.OpenPackImu object at 0x7f078a3169b0>, 'U0106-S0300': <openpack_torch.data.datasets.OpenPackImu object at 0x7f06920c5ae0>, 'U0106-S0500': <openpack_torch.data.datasets.OpenPackImu object at 0x7f078a31f910>}
# 2023-11-23 09:04:31 | INFO | openpack_torch.data.datamodule | dataset[submission]: None
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100% 7/7 [00:00<00:00, 228.94it/s]
# 2023-11-23 09:04:31 | INFO | openpack_torch.utils.test_helper | save t[shape=(50, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0100/t.npy
# 2023-11-23 09:04:31 | INFO | openpack_torch.utils.test_helper | save y[shape=(50, 11, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0100/y.npy
# 2023-11-23 09:04:31 | INFO | openpack_torch.utils.test_helper | save unixtime[shape=(50, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0100/unixtime.npy
# 2023-11-23 09:04:31 | INFO | openpack_torch.utils.test_helper | test on U0106-S0300
# 2023-11-23 09:04:31 | INFO | openpack_torch.data.datamodule | dataset[train]: None
# 2023-11-23 09:04:31 | INFO | openpack_torch.data.datamodule | dataset[val]: None
# 2023-11-23 09:04:31 | INFO | openpack_torch.data.datamodule | dataset[test]: {'U0106-S0100': <openpack_torch.data.datasets.OpenPackImu object at 0x7f069222d390>, 'U0106-S0300': <openpack_torch.data.datasets.OpenPackImu object at 0x7f0691fd8f40>, 'U0106-S0500': <openpack_torch.data.datasets.OpenPackImu object at 0x7f0777efa260>}
# 2023-11-23 09:04:31 | INFO | openpack_torch.data.datamodule | dataset[submission]: None
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100% 5/5 [00:00<00:00, 209.83it/s]
# 2023-11-23 09:04:31 | INFO | openpack_torch.utils.test_helper | save t[shape=(85, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0300/t.npy
# 2023-11-23 09:04:31 | INFO | openpack_torch.utils.test_helper | save y[shape=(85, 11, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0300/y.npy
# 2023-11-23 09:04:31 | INFO | openpack_torch.utils.test_helper | save unixtime[shape=(85, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0300/unixtime.npy
# 2023-11-23 09:04:31 | INFO | openpack_torch.utils.test_helper | test on U0106-S0500
# 2023-11-23 09:04:31 | INFO | openpack_torch.data.datamodule | dataset[train]: None
# 2023-11-23 09:04:31 | INFO | openpack_torch.data.datamodule | dataset[val]: None
# 2023-11-23 09:04:31 | INFO | openpack_torch.data.datamodule | dataset[test]: {'U0106-S0100': <openpack_torch.data.datasets.OpenPackImu object at 0x7f0777f2c910>, 'U0106-S0300': <openpack_torch.data.datasets.OpenPackImu object at 0x7f0777f5e320>, 'U0106-S0500': <openpack_torch.data.datasets.OpenPackImu object at 0x7f0777f936a0>}
# 2023-11-23 09:04:31 | INFO | openpack_torch.data.datamodule | dataset[submission]: None
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100% 3/3 [00:00<00:00, 154.30it/s]
# 2023-11-23 09:04:32 | INFO | openpack_torch.utils.test_helper | save t[shape=(103, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0500/t.npy
# 2023-11-23 09:04:32 | INFO | openpack_torch.utils.test_helper | save y[shape=(103, 11, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0500/y.npy
# 2023-11-23 09:04:32 | INFO | openpack_torch.utils.test_helper | save unixtime[shape=(103, 1800)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/pred/last/U0106-S0500/unixtime.npy
# 2023-11-23 09:04:32 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | 1 elements are missing from prediction.: [1637895693000]
# 2023-11-23 09:04:32 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | fill missing element at ts=1637895693000 (ind=2946) with 100.
# 2023-11-23 09:04:32 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | 1 elements are missing from prediction.: [1637905740000]
# 2023-11-23 09:04:32 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | fill missing element at ts=1637905740000 (ind=2059) with 100.
# 2023-11-23 09:04:32 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | 1 elements are missing from prediction.: [1637911136000]
# 2023-11-23 09:04:32 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | fill missing element at ts=1637911136000 (ind=1030) with 100.
# 2023-11-23 09:04:32 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | 1 elements are missing from prediction.: [1637895693000]
# 2023-11-23 09:04:32 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | fill missing element at ts=1637895693000 (ind=2946) with 100.
# 2023-11-23 09:04:32 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | 1 elements are missing from prediction.: [1637905740000]
# 2023-11-23 09:04:32 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | fill missing element at ts=1637905740000 (ind=2059) with 100.
# 2023-11-23 09:04:32 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | 1 elements are missing from prediction.: [1637911136000]
# 2023-11-23 09:04:32 | WARNING | openpack_toolkit.codalab.operation_segmentation.utils | fill missing element at ts=1637911136000 (ind=1030) with 100.
# 2023-11-23 09:04:32 | INFO | openpack_torch.utils.test_helper | write df_summary[shape=(96, 8)] to /content/data/log/benchmark1/I01-EXP1-V1-nb/openpack-operations-1hz-annotation/pilot-challenge-split/atr02-iot/DCL/adam-exp/LR0.001/RUN0/summary/last/test.csv
# 2023-11-23 09:04:32 | INFO | openpack_torch.utils.test_helper | df_summary:
#                      name    id  precision    recall        f1 support          key scenario
# 0               avg/macro    -1   0.226232  0.250336  0.220765    None  U0106-S0100       S1
# 1            avg/weighted    -1   0.241961  0.278928  0.245948    None  U0106-S0100       S1
# 2                 Picking   100   0.219124  0.190311  0.203704     289  U0106-S0100       S1
# 3     Relocate Item Label   200   0.353303  0.452756  0.396894     508  U0106-S0100       S1
# 4            Assemble Box   300   0.345389  0.402105  0.371595     475  U0106-S0100       S1
# 5            Insert Items   400   0.189145  0.500000  0.274463     230  U0106-S0100       S1
# 6               Close Box   500   0.254582  0.374251  0.303030     334  U0106-S0100       S1
# 7        Attach Box Label   600   0.163934  0.054945  0.082305     182  U0106-S0100       S1
# 8              Scan Label   700   0.000000  0.000000  0.000000     306  U0106-S0100       S1
# 9   Attach Shipping Label   800   0.333333  0.176724  0.230986     232  U0106-S0100       S1
# 10      Put on Back Table   900   0.298246  0.335526  0.315789     152  U0106-S0100       S1
# 11         Fill out Order  1000   0.105263  0.016736  0.028881     239  U0106-S0100       S1
# 12              avg/macro    -1   0.269185  0.260745  0.233576    None  U0106-S0300       S1
# 13           avg/weighted    -1   0.263656  0.281553  0.246477    None  U0106-S0300       S1
# 14                Picking   100   0.229508  0.158192  0.187291     177  U0106-S0300       S1
# 15    Relocate Item Label   200   0.306173  0.439716  0.360990     282  U0106-S0300       S1
# 16           Assemble Box   300   0.341463  0.432584  0.381660     356  U0106-S0300       S1
# 17           Insert Items   400   0.197826  0.522989  0.287066     174  U0106-S0300       S1
# 18              Close Box   500   0.249275  0.385650  0.302817     223  U0106-S0300       S1
# 19       Attach Box Label   600   0.275000  0.085938  0.130952     128  U0106-S0300       S1
# 20             Scan Label   700   0.000000  0.000000  0.000000     255  U0106-S0300       S1
# 21  Attach Shipping Label   800   0.368421  0.135484  0.198113     155  U0106-S0300       S1
# 22      Put on Back Table   900   0.360544  0.375887  0.368056     141  U0106-S0300       S1
# 23         Fill out Order  1000   0.363636  0.071006  0.118812     169  U0106-S0300       S1
# 24              avg/macro    -1   0.273228  0.261618  0.239351    None  U0106-S0500       S1
# 25           avg/weighted    -1   0.267608  0.273521  0.247829    None  U0106-S0500       S1
# 26                Picking   100   0.274510  0.162791  0.204380      86  U0106-S0500       S1
# 27    Relocate Item Label   200   0.242105  0.306667  0.270588     150  U0106-S0500       S1
# 28           Assemble Box   300   0.397059  0.395122  0.396088     205  U0106-S0500       S1
# 29           Insert Items   400   0.239796  0.552941  0.334520      85  U0106-S0500       S1
# 30              Close Box   500   0.169492  0.366972  0.231884     109  U0106-S0500       S1
# 31       Attach Box Label   600   0.333333  0.217391  0.263158      46  U0106-S0500       S1
# 32             Scan Label   700   0.000000  0.000000  0.000000     119  U0106-S0500       S1
# 33  Attach Shipping Label   800   0.625000  0.200000  0.303030      75  U0106-S0500       S1
# 34      Put on Back Table   900   0.317647  0.391304  0.350649      69  U0106-S0500       S1
# 35         Fill out Order  1000   0.133333  0.022989  0.039216      87  U0106-S0500       S1
# 36              avg/macro    -1   0.248521  0.255870  0.228489    None          all       S1
# 37           avg/weighted    -1   0.252917  0.278900  0.246339    None          all       S1
# 38                Picking   100   0.228774  0.175725  0.198770     552          all       S1
# 39    Relocate Item Label   200   0.321027  0.425532  0.365965     940          all       S1
# 40           Assemble Box   300   0.352649  0.411197  0.379679    1036          all       S1
# 41           Insert Items   400   0.200158  0.517382  0.288648     489          all       S1
# 42              Close Box   500   0.234142  0.376877  0.288838     666          all       S1
# 43       Attach Box Label   600   0.236641  0.087079  0.127310     356          all       S1
# 44             Scan Label   700   0.000000  0.000000  0.000000     680          all       S1
# 45  Attach Shipping Label   800   0.377451  0.166667  0.231231     462          all       S1
# 46      Put on Back Table   900   0.325062  0.361878  0.342484     362          all       S1
# 47         Fill out Order  1000   0.209302  0.036364  0.061962     495          all       S1
# 0               avg/macro    -1   0.226232  0.250336  0.220765    None  U0106-S0100      all
# 1            avg/weighted    -1   0.241961  0.278928  0.245948    None  U0106-S0100      all
# 2                 Picking   100   0.219124  0.190311  0.203704     289  U0106-S0100      all
# 3     Relocate Item Label   200   0.353303  0.452756  0.396894     508  U0106-S0100      all
# 4            Assemble Box   300   0.345389  0.402105  0.371595     475  U0106-S0100      all
# 5            Insert Items   400   0.189145  0.500000  0.274463     230  U0106-S0100      all
# 6               Close Box   500   0.254582  0.374251  0.303030     334  U0106-S0100      all
# 7        Attach Box Label   600   0.163934  0.054945  0.082305     182  U0106-S0100      all
# 8              Scan Label   700   0.000000  0.000000  0.000000     306  U0106-S0100      all
# 9   Attach Shipping Label   800   0.333333  0.176724  0.230986     232  U0106-S0100      all
# 10      Put on Back Table   900   0.298246  0.335526  0.315789     152  U0106-S0100      all
# 11         Fill out Order  1000   0.105263  0.016736  0.028881     239  U0106-S0100      all
# 12              avg/macro    -1   0.269185  0.260745  0.233576    None  U0106-S0300      all
# 13           avg/weighted    -1   0.263656  0.281553  0.246477    None  U0106-S0300      all
# 14                Picking   100   0.229508  0.158192  0.187291     177  U0106-S0300      all
# 15    Relocate Item Label   200   0.306173  0.439716  0.360990     282  U0106-S0300      all
# 16           Assemble Box   300   0.341463  0.432584  0.381660     356  U0106-S0300      all
# 17           Insert Items   400   0.197826  0.522989  0.287066     174  U0106-S0300      all
# 18              Close Box   500   0.249275  0.385650  0.302817     223  U0106-S0300      all
# 19       Attach Box Label   600   0.275000  0.085938  0.130952     128  U0106-S0300      all
# 20             Scan Label   700   0.000000  0.000000  0.000000     255  U0106-S0300      all
# 21  Attach Shipping Label   800   0.368421  0.135484  0.198113     155  U0106-S0300      all
# 22      Put on Back Table   900   0.360544  0.375887  0.368056     141  U0106-S0300      all
# 23         Fill out Order  1000   0.363636  0.071006  0.118812     169  U0106-S0300      all
# 24              avg/macro    -1   0.273228  0.261618  0.239351    None  U0106-S0500      all
# 25           avg/weighted    -1   0.267608  0.273521  0.247829    None  U0106-S0500      all
# 26                Picking   100   0.274510  0.162791  0.204380      86  U0106-S0500      all
# 27    Relocate Item Label   200   0.242105  0.306667  0.270588     150  U0106-S0500      all
# 28           Assemble Box   300   0.397059  0.395122  0.396088     205  U0106-S0500      all
# 29           Insert Items   400   0.239796  0.552941  0.334520      85  U0106-S0500      all
# 30              Close Box   500   0.169492  0.366972  0.231884     109  U0106-S0500      all
# 31       Attach Box Label   600   0.333333  0.217391  0.263158      46  U0106-S0500      all
# 32             Scan Label   700   0.000000  0.000000  0.000000     119  U0106-S0500      all
# 33  Attach Shipping Label   800   0.625000  0.200000  0.303030      75  U0106-S0500      all
# 34      Put on Back Table   900   0.317647  0.391304  0.350649      69  U0106-S0500      all
# 35         Fill out Order  1000   0.133333  0.022989  0.039216      87  U0106-S0500      all
# 36              avg/macro    -1   0.248521  0.255870  0.228489    None          all      all
# 37           avg/weighted    -1   0.252917  0.278900  0.246339    None          all      all
# 38                Picking   100   0.228774  0.175725  0.198770     552          all      all
# 39    Relocate Item Label   200   0.321027  0.425532  0.365965     940          all      all
# 40           Assemble Box   300   0.352649  0.411197  0.379679    1036          all      all
# 41           Insert Items   400   0.200158  0.517382  0.288648     489          all      all
# 42              Close Box   500   0.234142  0.376877  0.288838     666          all      all
# 43       Attach Box Label   600   0.236641  0.087079  0.127310     356          all      all
# 44             Scan Label   700   0.000000  0.000000  0.000000     680          all      all
# 45  Attach Shipping Label   800   0.377451  0.166667  0.231231     462          all      all
# 46      Put on Back Table   900   0.325062  0.361878  0.342484     362          all      all
# 47         Fill out Order  1000   0.209302  0.036364  0.061962     495          all      all

# %% [markdown]
# #### 評価指標:
#
# - Precision
# - Recall
# - F値 (F1-measure)
#
# F値のマクロ平均 (f1, name=avg/macoro)に注目

# %%
df_summary[df_summary["key"]=="all"]
# Out:
#                      name    id  precision    recall        f1 support  key scenario
# 36              avg/macro    -1   0.248521  0.255870  0.228489    None  all       S1
# 37           avg/weighted    -1   0.252917  0.278900  0.246339    None  all       S1
# 38                Picking   100   0.228774  0.175725  0.198770     552  all       S1
# 39    Relocate Item Label   200   0.321027  0.425532  0.365965     940  all       S1
# 40           Assemble Box   300   0.352649  0.411197  0.379679    1036  all       S1
# 41           Insert Items   400   0.200158  0.517382  0.288648     489  all       S1
# 42              Close Box   500   0.234142  0.376877  0.288838     666  all       S1
# 43       Attach Box Label   600   0.236641  0.087079  0.127310     356  all       S1
# 44             Scan Label   700   0.000000  0.000000  0.000000     680  all       S1
# 45  Attach Shipping Label   800   0.377451  0.166667  0.231231     462  all       S1
# 46      Put on Back Table   900   0.325062  0.361878  0.342484     362  all       S1
# 47         Fill out Order  1000   0.209302  0.036364  0.061962     495  all       S1
# 36              avg/macro    -1   0.248521  0.255870  0.228489    None  all      all
# 37           avg/weighted    -1   0.252917  0.278900  0.246339    None  all      all
# 38                Picking   100   0.228774  0.175725  0.198770     552  all      all
# 39    Relocate Item Label   200   0.321027  0.425532  0.365965     940  all      all
# 40           Assemble Box   300   0.352649  0.411197  0.379679    1036  all      all
# 41           Insert Items   400   0.200158  0.517382  0.288648     489  all      all
# 42              Close Box   500   0.234142  0.376877  0.288838     666  all      all
# 43       Attach Box Label   600   0.236641  0.087079  0.127310     356  all      all
# 44             Scan Label   700   0.000000  0.000000  0.000000     680  all      all
# 45  Attach Shipping Label   800   0.377451  0.166667  0.231231     462  all      all
# 46      Put on Back Table   900   0.325062  0.361878  0.342484     362  all      all
# 47         Fill out Order  1000   0.209302  0.036364  0.061962     495  all      all

# %% [markdown]
# #### 可視化

# %%
# 可視化したいセグメント
key = "U0106-S0500"

# 予測結果の取得
unixtimes = outputs[key]["unixtime"] 
t_idx = outputs[key]["t_idx"]
y = outputs[key]["y"]
y_softmax = softmax(y, axis=1)
print(f"unixtimes={unixtimes.shape}, t_idx={t_idx.shape}, y={y.shape}, y_softmax={y_softmax.shape}")
# Out:
# unixtimes=(103, 1800), t_idx=(103, 1800), y=(103, 11, 1800), y_softmax=(103, 11, 1800)

# %%
samples = (0, 10)

fig = plot_timeline(samples, t_idx, y_softmax, title_prefix=f"{cfg.model.name} | {key}")
fig.show()
# Out:
# prob=(11, 18000) pred=(18000,), gt=(18000,)

# %% [markdown]
# 学習前の図と比べて，出力はどうなったでしょうか？
# 赤い正解ラベルの付近が黄色くなっているかと思います．モデリングを工夫すると90%近くまでスコアが上がると思います．様々なモデルとパラメータをトライしてみてください．
